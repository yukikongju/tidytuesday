# %%
import pandas as pd
import numpy as np
import random

from itertools import chain
from sklearn.base import BaseEstimator, TransformerMixin
from nltk.corpus import wordnet

# %% [markdown]
# ### Get data

# %%
df = pd.read_csv('../data/data.csv')
df = df[:100]

# %%
df.head()
# Out:
#                                             Sentence Sentiment
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral

# %%
complete_text = " ".join(df['Sentence'])
words = [word.lower() for sentence in complete_text.split('.') for word in sentence.split(' ')]
# print(words)
df_freq = pd.value_counts(np.array(words)).reset_index()

# %%
len(words) * 0.025
# Out:
# 57.150000000000006

# %% [markdown]
# ### Synonym Replacement

# %%
class SynonymReplacement(BaseEstimator, TransformerMixin):

    """ 
    We want to perform synonym replacement with words that are meaningful. To 
    determine if a word if meaningful, we will use Zipft law
    """

    def __init__(self, max_synonyms = 3, perc_replacements = 0.025):
        """ 
        Parameters 
        ----------
        max_synonyms: int
            maximum of synonyms for each words
        perc_replacements: float
            percentage of words to be replaced
        """
        self.max_synonyms = max_synonyms
        self.perc_replacements = perc_replacements

    def fit(self, X, y=None):
        return self


    def transform(self, documents, labels): # TODO
        # 1. get list of words to replace with zipft law
        synonyms = self._get_words_to_replace(documents)

        # 2. get data augmentation (everytime we see word in list, we augment)
        new_documents = []
        synonyms_dict = {}
        for sentence, label in zip(documents, labels): 
            new_documents.append([sentence, label]) # add old sentence
            # add new sentences with synonym replacement
            words = sentence.split(' ')
            for i, word in enumerate(words):
                if word in synonyms:
                    # find list of synonym for word in not in dict
                    if word not in synonyms_dict: 
                        synonyms_dict[word] = self._get_synonyms(word)

                    # data augmentation
                    for synonym in synonyms_dict[word]: 
                        new_sentence_words = words[0:i-1] + [synonym] + words[0: i+1]\
                            if i + 1 < len(sentence) else words[0:i-1] + [synonym]
                        new_sentence = " ".join(new_sentence_words)
                        new_documents.append([new_sentence, label])


        return new_documents

    def _get_num_of_words_to_replace(self, documents): 
        """ 
        Function that return how many words to replace
        len(vocab) * perc
        """
        words = [word.lower() for sentence in complete_text.split('.') for word in sentence.split(' ')]
        return int(len(words) * self.perc_replacements)
        

    def _get_words_to_replace(self, documents): 
        """ 
        Function that get list of words to perform data augmentation on. 
        We choose the bottom from zipft law
        """
        # get word frequency count
        df_freq = self._get_word_frequency(documents)

        # get num words to find synonym
        num_words_to_replace = self._get_num_of_words_to_replace(documents)

        # find the list of words to replace
        words_to_replace = list(df_freq[:num_words_to_replace]['word'])

        return words_to_replace
        

    def _get_word_frequency(self, documents): 
        """ 
        Function that count word frequency 

        Parameters
        ----------
        documents: list of string

        Returns
        -------
        df: pandas dataframe
            dataframe with word frequency (col: word, count) in decreasing order
        """
        complete_text = " ".join(documents)
        words = [word.lower() for sentence in complete_text.split('.') for word in sentence.split(' ')]

        # remove selected words
        to_remove = [' ', ',', '', '-', '``', "'"]
        words = [word for word in words if word not in to_remove]
        
        freq = pd.value_counts(np.array(words)).rename_axis('word').reset_index(name='count')
        freq = freq.sort_values(by=['count'], ascending=True)

        return freq


    def _get_synonyms(self, word):
        """ 
        Function that return list of synonym using wordnet model

        Parameters
        ----------
        word: string
            word to find synonym for

        Returns
        -------
        synonym: list of string
            list of synonym. Include initial word
        """
        # FIXME: why does list change every time function is run

        # get all synonyms from wordnet
        synonym_tokens = wordnet.synsets(word)
        synonyms = list(set(chain.from_iterable([word.lemma_names() for word in synonym_tokens])))

        # get top synonym (current: first 5)
        top_synonyms = synonyms[:self.max_synonyms]

        # clean: replace '_' by ' '
        top_synonyms = [word.replace('_', ' ') for word in top_synonyms]

        return top_synonyms

# %%
replacement = SynonymReplacement()
replacement._get_word_frequency(df['Sentence'])
# Out:
#         word  count
# 459  estonia      1
# 605     fish      1
# 606      30%      1
# 607  co/ir2f      1
# 608  l+ñnnen      1
# ..       ...    ...
# 4          a     43
# 3         in     49
# 2         to     52
# 1         of     68
# 0        the     95
#
# [919 rows x 2 columns]

# %%
new_sentences = replacement.transform(df['Sentence'], df['Sentiment'])

# %%
print(len(new_sentences))
print(len(df['Sentence']))
# Out:
# 165
# 100

# %%
[sentence for i in range(3) for sentence in list(df['Sentence'])]
# Out:
# ["The GeoSolutions technology will leverage Benefon 's GPS solutions by providing Location Based Search Technology , a Communities Platform , location relevant multimedia content and a new and powerful commercial model .",
#  '$ESI on lows, down $1.50 to $2.50 BK a real possibility',
#  "For the last quarter of 2010 , Componenta 's net sales doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .",
#  'According to the Finnish-Russian Chamber of Commerce , all the major construction companies of Finland are operating in Russia .',
#  'The Swedish buyout firm has sold its remaining 22.4 percent stake , almost eighteen months after taking the company public in Finland .',
#  "$SPY wouldn't be surprised to see a green close",
#  "Shell's $70 Billion BG Deal Meets Shareholder Skepticism",
#  'SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANGE RELEASE OCTOBER 14 , 2008 AT 2:45 PM The Company updates its full year outlook and estimates its results to remain at loss for the full year .',
#  "Kone 's net sales rose by some 14 % year-on-year in the first nine months of 2008 .",
#  "The Stockmann department store will have a total floor space of over 8,000 square metres and Stockmann 's investment in the project will have a price tag of about EUR 12 million .",
#  'Circulation revenue has increased by 5 % in Finland and 4 % in Sweden in 2008 .',
#  '$SAP Q1 disappoints as #software licenses down. Real problem? #Cloud growth trails $MSFT $ORCL $GOOG $CRM $ADBE https://t.co/jNDphllzq5',
#  'The subdivision made sales revenues last year of EUR 480.7 million EUR 414.9 million in 2008 , and operating profits of EUR 44.5 million EUR 7.4 million .',
#  'Viking Line has canceled some services .',
#  "Ahlstrom Corporation STOCK EXCHANGE ANNOUNCEMENT 7.2.2007 at 10.30 A total of 56,955 new shares of Ahlstrom Corporation have been subscribed with option rights under the company 's stock option programs I 2001 and II 2001 .",
#  '$FB gone green on day',
#  '$MSFT SQL Server revenue grew double-digit with SQL Server Premium revenue growing over 30% http://stks.co/ir2F',
#  "According to L+ñnnen Tehtaat 's CEO Matti Karppinen , the company aims to deliver fish products to its customers a day earlier than it currently does .",
#  "The company 's share is quoted on NASDAQ OMX Helsinki Rautaruukki Oyj : RTRKS .",
#  'Elcoteq SE is listed on the Nasdaq OMX Helsinki Ltd. .',
#  'Two of these contracts are for turntable anode vibrocompactors that will be delivered to Gansu Hualu Aluminum Co Ltd and another unnamed costumer .',
#  'Aviva, Friends Life top forecasts ahead of 5.6 billion pound merger',
#  'In stead of being based on a soft drink , as is usual , the Teho energy drink is made with fresh water .',
#  "The company plans to increase the unit 's specialist staff to several dozen -- depending on the market situation during 2010 .",
#  'The company closed last year with a turnover of about four million euros .',
#  'Shire CEO steps up drive to get Baxalta board talking',
#  'Costco: A Premier Retail Dividend Play https://t.co/Fa5cnh2t0t $COST',
#  'The five-storey , eco-efficient building will have a gross floor area of about 15,000 sq m. It will also include apartments .',
#  'The first installment of the Cinema Series concludes with a profile of Finnish inventor Olavi Linden , whose personal artistic journey and work at Fiskars has led to dozens of design awards .',
#  'All are welcome .',
#  "Stockmann and Swedish sector company AB Lindex entered into an agreement on September 30 , 2007 , whereby Stockmann , or a wholly-owned subsidiary of it , will make a public tender offer for all of Lindex 's issued shares .",
#  "HUHTAMAKI OYJ STOCK EXCHANGE RELEASE , 16.9.2008 AT 13.32 Huhtamaki 's Capital Markets Day for institutional investors and analysts is held in Espoo , September 16 , 2008 starting at 13.30 pm Finnish time .",
#  '`` We are pleased to welcome Tapeks Noma into Cramo group .',
#  '- Profit before taxes was EUR 105.9 82.7 million .',
#  'Royal Dutch Shell to Buy BG Group for Nearly $70 Billion',
#  'FinancialWire tm is not a press release service , and receives no compensation for its news , opinions or distributions .',
#  "ASSA ABLOY Kaupthing Bank gave a ` neutral ' recommendation and a share price target of 174 crowns $ 24.7 - 19 euro on Swedish lock maker Assa Abloy AB .",
#  'The item included restructuring costs of EUR1 .6 m , while a year earlier they were EUR13 .1 m. Diluted EPS stood at EUR0 .3 versus a loss per share of EUR 0.1 .',
#  'In 2005 the bank posted a net profit of Lt 8.2 mn .',
#  '$AAPL afternoon selloff as usual will be brutal. get ready to lose a ton of money.',
#  '$TSLA recalling pretty much every single model X @cnnbrk got to short that even at work you jump in money trade',
#  "Dolce & Gabbana has asked the European Union to declare Marimekko Corporation 's `` Unikko '' floral pattern trademark invalid , in a continuing dispute between the two companies .",
#  'InterContinental Hotels first-quarter global room revenue lags estimates',
#  'According to Finnish pension insurance company Varma , Varma was the recipient of over two thirds of the revenue of the earnings-related pension cover that was under competitive tendering in Finland .',
#  'A portion , $ 12.5 million , will be recorded as part of its winnings in a prior patent dispute with Finnish phone maker Nokia Oyj .',
#  'L&G still paying price for dividend cut during crisis, chief says',
#  'The volume of investments in the two phases of the project is estimated at USD 300mn ( EUR 215.03 mn ) .',
#  "Russia accounted for 9 % of the Lagardere magazine division 's revenue , or EUR 114.40 mn ( USD 148.11 mn ) in 2009 , the USA - for 18 % .",
#  'The company also estimates the already carried out investments to lead to an increase in its net sales for 2010 from 2009 when they reached EUR 141.7 million .',
#  'Profit of the accounting period was EUR 0.3 mn .',
#  'The six breweries recorded a 5.2 percent growth in domestic beer sales last year to 270.21 million liters , from 256.88 million liters sold in 2005 .',
#  "In August-October 2010 , the company 's result before taxes totalled EUR 9.6 mn , up from EUR 0.5 mn in the corresponding period in 2009 .",
#  "Systeemitiimi 's sales and project resources will also be strengthened , director Paul Skogberg said .",
#  'Tesco share price jumps as Q3 sales top estimates',
#  'The fine print is here .',
#  'The price for logs has clearly improved from 2009 and also the price of pulpwood has gone up .',
#  'Thus , SysOpen Digia has , in accordance with Chapter 14 Section 21 of the Finnish Companies Act 29.9.1978 - 734 , obtained title to all the shares of Sentera that are to be redeemed .',
#  'Diluted earnings per share ( EPS ) fell to EUR 0.63 from EUR 1.71 .',
#  'At 3:37 p.m. Eastern time , a block of 2,400 contracts changed hands at a bid price of $ 0.45 .',
#  'Some of the most recent technology deliveries include refinery technology to Anrak Aluminium , an iron ore pelletizing plant to Tata Steel and iron ore sintering plants to Bhushan Steel .',
#  '$VIPS similar pattern like beginning of May. Did u sell? Same now..will go up much higher after this drop.',
#  'The firm generated sales of 187 mln eur in 2005 .',
#  'Stora Enso has also had meetings with the labor authorities , Employment and Economic Development Centres and representatives of the government in order to find solutions .',
#  'AstraZeneca profit down as sales of stalwarts fade',
#  'RT @andrewnyquist Chartology: Yahoo: http://stks.co/1itr $YHOO  Crazy looking chart, but nearing breakout resistance line...',
#  'Most bullish stocks on Twitter during this dip. $YHOO $GDX $GOOGL $STZ $GOLD $EW $VZ $CELG $SBUX $SCTY more: https://t.co/iuZJelfwt3',
#  "Finnish GeoSentric 's net sales decreased to EUR 939,000 in January-March 2009 .",
#  'Cohen & Steers , Inc. : 5 534 626 shares representing 4.985 % of the share capital and voting rights .',
#  'More staff has been recruited in Japan to further complement its network of close to 50 service locations in more than 20 countries worldwide .',
#  'Paper companies were in negative territories , with Stora Enso R shedding 1.62 pct to 12.73 eur , UPM-Kymmene down 0.80 pct at 18.64 eur and M-real B 0.18 pct lower at 5.57 eur .',
#  "Kauko-Telko 's centralized administration will be dissolved and appropriate parts of it will be transferred to operating activities and Group administration by the end of the year .",
#  'Operating profit for the quarter April-June 2006 amounted to EUR182 .2 m on sales of EUR3 .62 bn .',
#  'Atria chose the DeLight to attract consumers in the 25-45 age group to its Atria Fresh range of microwaveable meals .',
#  'Finnish IT solutions provider Affecto Oyj HEL : AFE1V said today its slipped to a net loss of EUR 115,000 USD 152,000 in the second quarter of 2010 from a profit of EUR 845,000 in the corresponding period a year earlier .',
#  'US sanctions put Gazprom-Shell alliance plans in jeopardy',
#  'Profit for the period was EUR 10.9 mn , down from EUR 14.3 mn in 2009 .',
#  'Profit for the period was EUR 5.9 mn , up from EUR 1.3 mn .',
#  'Operating profit fell to EUR 20.3 mn from EUR 74.2 mn in the second quarter of 2008 .',
#  'However , sales returned to growth in April-June 2010 , CEO Pekka Eloholma said .',
#  'Operating profit totaled EUR 18.6 mn or 8.3 % of net sales .',
#  'Changes in the market situation and tougher price competition have substantially reduced demand for bread packaging manufactured at the Kauhava plant , according to the company .',
#  'In connection with the deal , Digia will employ 19 persons from Nokia in Oslo and in Silicon Valley in the USA .',
#  "The Brazilian unit of Finnish security solutions provider F-Secure signed up 1,500 new clients last year , online news source Reseller Web quoted the division 's commercial director , Vladimir Brand+úo , as saying .",
#  "The fair value of the company 's investment properties went down to EUR 2.768 billion at the end of 2009 from EUR 2.916 billion a year earlier .",
#  'Dealers said the share was largely hit by investor disappointment about a refining margin of just 9.48 usd per barrel for the quarter and the performance of its shipping unit , which saw EBIT drop to 5 mln eur from 20 mln eur a year amid a fall in volumes and tanker rates .',
#  "` It is a testament to the quality of our LTE solution and our commitment to the Japanese market ' , he added .",
#  "The companies ' aim is to finalize the negotiations and sign the contracts at the start of October 2008 .",
#  'Metso Foundries Jyvaskyla Oy will discontinue production on this line by 30 September 2008 , the company said .',
#  "A total six of the polled analysts rated M-real -- two gave `` buy '' - `` accumulate '' , three gave `` hold '' and only one gave `` sell '' .",
#  'In September 2010 , the Finnish group agreed to buy Danish company Rose Poultry A-S for up to EUR23 .9 m in a combination of cash and stock .',
#  '$YANG Double bottom 5.2',
#  'Tesco share price down as grocer faces SFO investigation outcome',
#  '$aapl news is becoming very bullish again http://stks.co/tMU',
#  'GS Engineering will install the valves at a liquefied natural gas LNG plant it has built for UAE LNG extraction and gas plants operator GASCO in Ruwais , UAE .',
#  'The percentages of shares and voting rights have been calculated in proportion to the total number of shares registered with the Trade Register and the total number of voting rights related to them .',
#  "M-Real said there are ` no grounds ' for the rumors , which ` have been circulating in the market for some months . '",
#  'Lember said the matter was topical also in Estonia , where a bill has been drafted at the Social Affairs Ministry that would scrap old-age pensions on favorable conditions .',
#  "- Moody 's said it gave P A1 long-term senior unsecured and P P-1 short-term debt ratings to Finnish lender Aktia Bank 's EUR1bn USD1 .4 bn euro medium-term note EMTN program of 25 March 2011 .",
#  '$TSLA recall',
#  "The liquidity providing was interrupted on May 11 , 2007 when Aspocomp Group Oyj 's shares traded below 0.50 cent ( Aspocomp 's stock exchange release 11.5.2007 ) .",
#  "The GeoSolutions technology will leverage Benefon 's GPS solutions by providing Location Based Search Technology , a Communities Platform , location relevant multimedia content and a new and powerful commercial model .",
#  '$ESI on lows, down $1.50 to $2.50 BK a real possibility',
#  "For the last quarter of 2010 , Componenta 's net sales doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .",
#  'According to the Finnish-Russian Chamber of Commerce , all the major construction companies of Finland are operating in Russia .',
#  'The Swedish buyout firm has sold its remaining 22.4 percent stake , almost eighteen months after taking the company public in Finland .',
#  "$SPY wouldn't be surprised to see a green close",
#  "Shell's $70 Billion BG Deal Meets Shareholder Skepticism",
#  'SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANGE RELEASE OCTOBER 14 , 2008 AT 2:45 PM The Company updates its full year outlook and estimates its results to remain at loss for the full year .',
#  "Kone 's net sales rose by some 14 % year-on-year in the first nine months of 2008 .",
#  "The Stockmann department store will have a total floor space of over 8,000 square metres and Stockmann 's investment in the project will have a price tag of about EUR 12 million .",
#  'Circulation revenue has increased by 5 % in Finland and 4 % in Sweden in 2008 .',
#  '$SAP Q1 disappoints as #software licenses down. Real problem? #Cloud growth trails $MSFT $ORCL $GOOG $CRM $ADBE https://t.co/jNDphllzq5',
#  'The subdivision made sales revenues last year of EUR 480.7 million EUR 414.9 million in 2008 , and operating profits of EUR 44.5 million EUR 7.4 million .',
#  'Viking Line has canceled some services .',
#  "Ahlstrom Corporation STOCK EXCHANGE ANNOUNCEMENT 7.2.2007 at 10.30 A total of 56,955 new shares of Ahlstrom Corporation have been subscribed with option rights under the company 's stock option programs I 2001 and II 2001 .",
#  '$FB gone green on day',
#  '$MSFT SQL Server revenue grew double-digit with SQL Server Premium revenue growing over 30% http://stks.co/ir2F',
#  "According to L+ñnnen Tehtaat 's CEO Matti Karppinen , the company aims to deliver fish products to its customers a day earlier than it currently does .",
#  "The company 's share is quoted on NASDAQ OMX Helsinki Rautaruukki Oyj : RTRKS .",
#  'Elcoteq SE is listed on the Nasdaq OMX Helsinki Ltd. .',
#  'Two of these contracts are for turntable anode vibrocompactors that will be delivered to Gansu Hualu Aluminum Co Ltd and another unnamed costumer .',
#  'Aviva, Friends Life top forecasts ahead of 5.6 billion pound merger',
#  'In stead of being based on a soft drink , as is usual , the Teho energy drink is made with fresh water .',
#  "The company plans to increase the unit 's specialist staff to several dozen -- depending on the market situation during 2010 .",
#  'The company closed last year with a turnover of about four million euros .',
#  'Shire CEO steps up drive to get Baxalta board talking',
#  'Costco: A Premier Retail Dividend Play https://t.co/Fa5cnh2t0t $COST',
#  'The five-storey , eco-efficient building will have a gross floor area of about 15,000 sq m. It will also include apartments .',
#  'The first installment of the Cinema Series concludes with a profile of Finnish inventor Olavi Linden , whose personal artistic journey and work at Fiskars has led to dozens of design awards .',
#  'All are welcome .',
#  "Stockmann and Swedish sector company AB Lindex entered into an agreement on September 30 , 2007 , whereby Stockmann , or a wholly-owned subsidiary of it , will make a public tender offer for all of Lindex 's issued shares .",
#  "HUHTAMAKI OYJ STOCK EXCHANGE RELEASE , 16.9.2008 AT 13.32 Huhtamaki 's Capital Markets Day for institutional investors and analysts is held in Espoo , September 16 , 2008 starting at 13.30 pm Finnish time .",
#  '`` We are pleased to welcome Tapeks Noma into Cramo group .',
#  '- Profit before taxes was EUR 105.9 82.7 million .',
#  'Royal Dutch Shell to Buy BG Group for Nearly $70 Billion',
#  'FinancialWire tm is not a press release service , and receives no compensation for its news , opinions or distributions .',
#  "ASSA ABLOY Kaupthing Bank gave a ` neutral ' recommendation and a share price target of 174 crowns $ 24.7 - 19 euro on Swedish lock maker Assa Abloy AB .",
#  'The item included restructuring costs of EUR1 .6 m , while a year earlier they were EUR13 .1 m. Diluted EPS stood at EUR0 .3 versus a loss per share of EUR 0.1 .',
#  'In 2005 the bank posted a net profit of Lt 8.2 mn .',
#  '$AAPL afternoon selloff as usual will be brutal. get ready to lose a ton of money.',
#  '$TSLA recalling pretty much every single model X @cnnbrk got to short that even at work you jump in money trade',
#  "Dolce & Gabbana has asked the European Union to declare Marimekko Corporation 's `` Unikko '' floral pattern trademark invalid , in a continuing dispute between the two companies .",
#  'InterContinental Hotels first-quarter global room revenue lags estimates',
#  'According to Finnish pension insurance company Varma , Varma was the recipient of over two thirds of the revenue of the earnings-related pension cover that was under competitive tendering in Finland .',
#  'A portion , $ 12.5 million , will be recorded as part of its winnings in a prior patent dispute with Finnish phone maker Nokia Oyj .',
#  'L&G still paying price for dividend cut during crisis, chief says',
#  'The volume of investments in the two phases of the project is estimated at USD 300mn ( EUR 215.03 mn ) .',
#  "Russia accounted for 9 % of the Lagardere magazine division 's revenue , or EUR 114.40 mn ( USD 148.11 mn ) in 2009 , the USA - for 18 % .",
#  'The company also estimates the already carried out investments to lead to an increase in its net sales for 2010 from 2009 when they reached EUR 141.7 million .',
#  'Profit of the accounting period was EUR 0.3 mn .',
#  'The six breweries recorded a 5.2 percent growth in domestic beer sales last year to 270.21 million liters , from 256.88 million liters sold in 2005 .',
#  "In August-October 2010 , the company 's result before taxes totalled EUR 9.6 mn , up from EUR 0.5 mn in the corresponding period in 2009 .",
#  "Systeemitiimi 's sales and project resources will also be strengthened , director Paul Skogberg said .",
#  'Tesco share price jumps as Q3 sales top estimates',
#  'The fine print is here .',
#  'The price for logs has clearly improved from 2009 and also the price of pulpwood has gone up .',
#  'Thus , SysOpen Digia has , in accordance with Chapter 14 Section 21 of the Finnish Companies Act 29.9.1978 - 734 , obtained title to all the shares of Sentera that are to be redeemed .',
#  'Diluted earnings per share ( EPS ) fell to EUR 0.63 from EUR 1.71 .',
#  'At 3:37 p.m. Eastern time , a block of 2,400 contracts changed hands at a bid price of $ 0.45 .',
#  'Some of the most recent technology deliveries include refinery technology to Anrak Aluminium , an iron ore pelletizing plant to Tata Steel and iron ore sintering plants to Bhushan Steel .',
#  '$VIPS similar pattern like beginning of May. Did u sell? Same now..will go up much higher after this drop.',
#  'The firm generated sales of 187 mln eur in 2005 .',
#  'Stora Enso has also had meetings with the labor authorities , Employment and Economic Development Centres and representatives of the government in order to find solutions .',
#  'AstraZeneca profit down as sales of stalwarts fade',
#  'RT @andrewnyquist Chartology: Yahoo: http://stks.co/1itr $YHOO  Crazy looking chart, but nearing breakout resistance line...',
#  'Most bullish stocks on Twitter during this dip. $YHOO $GDX $GOOGL $STZ $GOLD $EW $VZ $CELG $SBUX $SCTY more: https://t.co/iuZJelfwt3',
#  "Finnish GeoSentric 's net sales decreased to EUR 939,000 in January-March 2009 .",
#  'Cohen & Steers , Inc. : 5 534 626 shares representing 4.985 % of the share capital and voting rights .',
#  'More staff has been recruited in Japan to further complement its network of close to 50 service locations in more than 20 countries worldwide .',
#  'Paper companies were in negative territories , with Stora Enso R shedding 1.62 pct to 12.73 eur , UPM-Kymmene down 0.80 pct at 18.64 eur and M-real B 0.18 pct lower at 5.57 eur .',
#  "Kauko-Telko 's centralized administration will be dissolved and appropriate parts of it will be transferred to operating activities and Group administration by the end of the year .",
#  'Operating profit for the quarter April-June 2006 amounted to EUR182 .2 m on sales of EUR3 .62 bn .',
#  'Atria chose the DeLight to attract consumers in the 25-45 age group to its Atria Fresh range of microwaveable meals .',
#  'Finnish IT solutions provider Affecto Oyj HEL : AFE1V said today its slipped to a net loss of EUR 115,000 USD 152,000 in the second quarter of 2010 from a profit of EUR 845,000 in the corresponding period a year earlier .',
#  'US sanctions put Gazprom-Shell alliance plans in jeopardy',
#  'Profit for the period was EUR 10.9 mn , down from EUR 14.3 mn in 2009 .',
#  'Profit for the period was EUR 5.9 mn , up from EUR 1.3 mn .',
#  'Operating profit fell to EUR 20.3 mn from EUR 74.2 mn in the second quarter of 2008 .',
#  'However , sales returned to growth in April-June 2010 , CEO Pekka Eloholma said .',
#  'Operating profit totaled EUR 18.6 mn or 8.3 % of net sales .',
#  'Changes in the market situation and tougher price competition have substantially reduced demand for bread packaging manufactured at the Kauhava plant , according to the company .',
#  'In connection with the deal , Digia will employ 19 persons from Nokia in Oslo and in Silicon Valley in the USA .',
#  "The Brazilian unit of Finnish security solutions provider F-Secure signed up 1,500 new clients last year , online news source Reseller Web quoted the division 's commercial director , Vladimir Brand+úo , as saying .",
#  "The fair value of the company 's investment properties went down to EUR 2.768 billion at the end of 2009 from EUR 2.916 billion a year earlier .",
#  'Dealers said the share was largely hit by investor disappointment about a refining margin of just 9.48 usd per barrel for the quarter and the performance of its shipping unit , which saw EBIT drop to 5 mln eur from 20 mln eur a year amid a fall in volumes and tanker rates .',
#  "` It is a testament to the quality of our LTE solution and our commitment to the Japanese market ' , he added .",
#  "The companies ' aim is to finalize the negotiations and sign the contracts at the start of October 2008 .",
#  'Metso Foundries Jyvaskyla Oy will discontinue production on this line by 30 September 2008 , the company said .',
#  "A total six of the polled analysts rated M-real -- two gave `` buy '' - `` accumulate '' , three gave `` hold '' and only one gave `` sell '' .",
#  'In September 2010 , the Finnish group agreed to buy Danish company Rose Poultry A-S for up to EUR23 .9 m in a combination of cash and stock .',
#  '$YANG Double bottom 5.2',
#  'Tesco share price down as grocer faces SFO investigation outcome',
#  '$aapl news is becoming very bullish again http://stks.co/tMU',
#  'GS Engineering will install the valves at a liquefied natural gas LNG plant it has built for UAE LNG extraction and gas plants operator GASCO in Ruwais , UAE .',
#  'The percentages of shares and voting rights have been calculated in proportion to the total number of shares registered with the Trade Register and the total number of voting rights related to them .',
#  "M-Real said there are ` no grounds ' for the rumors , which ` have been circulating in the market for some months . '",
#  'Lember said the matter was topical also in Estonia , where a bill has been drafted at the Social Affairs Ministry that would scrap old-age pensions on favorable conditions .',
#  "- Moody 's said it gave P A1 long-term senior unsecured and P P-1 short-term debt ratings to Finnish lender Aktia Bank 's EUR1bn USD1 .4 bn euro medium-term note EMTN program of 25 March 2011 .",
#  '$TSLA recall',
#  "The liquidity providing was interrupted on May 11 , 2007 when Aspocomp Group Oyj 's shares traded below 0.50 cent ( Aspocomp 's stock exchange release 11.5.2007 ) .",
#  "The GeoSolutions technology will leverage Benefon 's GPS solutions by providing Location Based Search Technology , a Communities Platform , location relevant multimedia content and a new and powerful commercial model .",
#  '$ESI on lows, down $1.50 to $2.50 BK a real possibility',
#  "For the last quarter of 2010 , Componenta 's net sales doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .",
#  'According to the Finnish-Russian Chamber of Commerce , all the major construction companies of Finland are operating in Russia .',
#  'The Swedish buyout firm has sold its remaining 22.4 percent stake , almost eighteen months after taking the company public in Finland .',
#  "$SPY wouldn't be surprised to see a green close",
#  "Shell's $70 Billion BG Deal Meets Shareholder Skepticism",
#  'SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANGE RELEASE OCTOBER 14 , 2008 AT 2:45 PM The Company updates its full year outlook and estimates its results to remain at loss for the full year .',
#  "Kone 's net sales rose by some 14 % year-on-year in the first nine months of 2008 .",
#  "The Stockmann department store will have a total floor space of over 8,000 square metres and Stockmann 's investment in the project will have a price tag of about EUR 12 million .",
#  'Circulation revenue has increased by 5 % in Finland and 4 % in Sweden in 2008 .',
#  '$SAP Q1 disappoints as #software licenses down. Real problem? #Cloud growth trails $MSFT $ORCL $GOOG $CRM $ADBE https://t.co/jNDphllzq5',
#  'The subdivision made sales revenues last year of EUR 480.7 million EUR 414.9 million in 2008 , and operating profits of EUR 44.5 million EUR 7.4 million .',
#  'Viking Line has canceled some services .',
#  "Ahlstrom Corporation STOCK EXCHANGE ANNOUNCEMENT 7.2.2007 at 10.30 A total of 56,955 new shares of Ahlstrom Corporation have been subscribed with option rights under the company 's stock option programs I 2001 and II 2001 .",
#  '$FB gone green on day',
#  '$MSFT SQL Server revenue grew double-digit with SQL Server Premium revenue growing over 30% http://stks.co/ir2F',
#  "According to L+ñnnen Tehtaat 's CEO Matti Karppinen , the company aims to deliver fish products to its customers a day earlier than it currently does .",
#  "The company 's share is quoted on NASDAQ OMX Helsinki Rautaruukki Oyj : RTRKS .",
#  'Elcoteq SE is listed on the Nasdaq OMX Helsinki Ltd. .',
#  'Two of these contracts are for turntable anode vibrocompactors that will be delivered to Gansu Hualu Aluminum Co Ltd and another unnamed costumer .',
#  'Aviva, Friends Life top forecasts ahead of 5.6 billion pound merger',
#  'In stead of being based on a soft drink , as is usual , the Teho energy drink is made with fresh water .',
#  "The company plans to increase the unit 's specialist staff to several dozen -- depending on the market situation during 2010 .",
#  'The company closed last year with a turnover of about four million euros .',
#  'Shire CEO steps up drive to get Baxalta board talking',
#  'Costco: A Premier Retail Dividend Play https://t.co/Fa5cnh2t0t $COST',
#  'The five-storey , eco-efficient building will have a gross floor area of about 15,000 sq m. It will also include apartments .',
#  'The first installment of the Cinema Series concludes with a profile of Finnish inventor Olavi Linden , whose personal artistic journey and work at Fiskars has led to dozens of design awards .',
#  'All are welcome .',
#  "Stockmann and Swedish sector company AB Lindex entered into an agreement on September 30 , 2007 , whereby Stockmann , or a wholly-owned subsidiary of it , will make a public tender offer for all of Lindex 's issued shares .",
#  "HUHTAMAKI OYJ STOCK EXCHANGE RELEASE , 16.9.2008 AT 13.32 Huhtamaki 's Capital Markets Day for institutional investors and analysts is held in Espoo , September 16 , 2008 starting at 13.30 pm Finnish time .",
#  '`` We are pleased to welcome Tapeks Noma into Cramo group .',
#  '- Profit before taxes was EUR 105.9 82.7 million .',
#  'Royal Dutch Shell to Buy BG Group for Nearly $70 Billion',
#  'FinancialWire tm is not a press release service , and receives no compensation for its news , opinions or distributions .',
#  "ASSA ABLOY Kaupthing Bank gave a ` neutral ' recommendation and a share price target of 174 crowns $ 24.7 - 19 euro on Swedish lock maker Assa Abloy AB .",
#  'The item included restructuring costs of EUR1 .6 m , while a year earlier they were EUR13 .1 m. Diluted EPS stood at EUR0 .3 versus a loss per share of EUR 0.1 .',
#  'In 2005 the bank posted a net profit of Lt 8.2 mn .',
#  '$AAPL afternoon selloff as usual will be brutal. get ready to lose a ton of money.',
#  '$TSLA recalling pretty much every single model X @cnnbrk got to short that even at work you jump in money trade',
#  "Dolce & Gabbana has asked the European Union to declare Marimekko Corporation 's `` Unikko '' floral pattern trademark invalid , in a continuing dispute between the two companies .",
#  'InterContinental Hotels first-quarter global room revenue lags estimates',
#  'According to Finnish pension insurance company Varma , Varma was the recipient of over two thirds of the revenue of the earnings-related pension cover that was under competitive tendering in Finland .',
#  'A portion , $ 12.5 million , will be recorded as part of its winnings in a prior patent dispute with Finnish phone maker Nokia Oyj .',
#  'L&G still paying price for dividend cut during crisis, chief says',
#  'The volume of investments in the two phases of the project is estimated at USD 300mn ( EUR 215.03 mn ) .',
#  "Russia accounted for 9 % of the Lagardere magazine division 's revenue , or EUR 114.40 mn ( USD 148.11 mn ) in 2009 , the USA - for 18 % .",
#  'The company also estimates the already carried out investments to lead to an increase in its net sales for 2010 from 2009 when they reached EUR 141.7 million .',
#  'Profit of the accounting period was EUR 0.3 mn .',
#  'The six breweries recorded a 5.2 percent growth in domestic beer sales last year to 270.21 million liters , from 256.88 million liters sold in 2005 .',
#  "In August-October 2010 , the company 's result before taxes totalled EUR 9.6 mn , up from EUR 0.5 mn in the corresponding period in 2009 .",
#  "Systeemitiimi 's sales and project resources will also be strengthened , director Paul Skogberg said .",
#  'Tesco share price jumps as Q3 sales top estimates',
#  'The fine print is here .',
#  'The price for logs has clearly improved from 2009 and also the price of pulpwood has gone up .',
#  'Thus , SysOpen Digia has , in accordance with Chapter 14 Section 21 of the Finnish Companies Act 29.9.1978 - 734 , obtained title to all the shares of Sentera that are to be redeemed .',
#  'Diluted earnings per share ( EPS ) fell to EUR 0.63 from EUR 1.71 .',
#  'At 3:37 p.m. Eastern time , a block of 2,400 contracts changed hands at a bid price of $ 0.45 .',
#  'Some of the most recent technology deliveries include refinery technology to Anrak Aluminium , an iron ore pelletizing plant to Tata Steel and iron ore sintering plants to Bhushan Steel .',
#  '$VIPS similar pattern like beginning of May. Did u sell? Same now..will go up much higher after this drop.',
#  'The firm generated sales of 187 mln eur in 2005 .',
#  'Stora Enso has also had meetings with the labor authorities , Employment and Economic Development Centres and representatives of the government in order to find solutions .',
#  'AstraZeneca profit down as sales of stalwarts fade',
#  'RT @andrewnyquist Chartology: Yahoo: http://stks.co/1itr $YHOO  Crazy looking chart, but nearing breakout resistance line...',
#  'Most bullish stocks on Twitter during this dip. $YHOO $GDX $GOOGL $STZ $GOLD $EW $VZ $CELG $SBUX $SCTY more: https://t.co/iuZJelfwt3',
#  "Finnish GeoSentric 's net sales decreased to EUR 939,000 in January-March 2009 .",
#  'Cohen & Steers , Inc. : 5 534 626 shares representing 4.985 % of the share capital and voting rights .',
#  'More staff has been recruited in Japan to further complement its network of close to 50 service locations in more than 20 countries worldwide .',
#  'Paper companies were in negative territories , with Stora Enso R shedding 1.62 pct to 12.73 eur , UPM-Kymmene down 0.80 pct at 18.64 eur and M-real B 0.18 pct lower at 5.57 eur .',
#  "Kauko-Telko 's centralized administration will be dissolved and appropriate parts of it will be transferred to operating activities and Group administration by the end of the year .",
#  'Operating profit for the quarter April-June 2006 amounted to EUR182 .2 m on sales of EUR3 .62 bn .',
#  'Atria chose the DeLight to attract consumers in the 25-45 age group to its Atria Fresh range of microwaveable meals .',
#  'Finnish IT solutions provider Affecto Oyj HEL : AFE1V said today its slipped to a net loss of EUR 115,000 USD 152,000 in the second quarter of 2010 from a profit of EUR 845,000 in the corresponding period a year earlier .',
#  'US sanctions put Gazprom-Shell alliance plans in jeopardy',
#  'Profit for the period was EUR 10.9 mn , down from EUR 14.3 mn in 2009 .',
#  'Profit for the period was EUR 5.9 mn , up from EUR 1.3 mn .',
#  'Operating profit fell to EUR 20.3 mn from EUR 74.2 mn in the second quarter of 2008 .',
#  'However , sales returned to growth in April-June 2010 , CEO Pekka Eloholma said .',
#  'Operating profit totaled EUR 18.6 mn or 8.3 % of net sales .',
#  'Changes in the market situation and tougher price competition have substantially reduced demand for bread packaging manufactured at the Kauhava plant , according to the company .',
#  'In connection with the deal , Digia will employ 19 persons from Nokia in Oslo and in Silicon Valley in the USA .',
#  "The Brazilian unit of Finnish security solutions provider F-Secure signed up 1,500 new clients last year , online news source Reseller Web quoted the division 's commercial director , Vladimir Brand+úo , as saying .",
#  "The fair value of the company 's investment properties went down to EUR 2.768 billion at the end of 2009 from EUR 2.916 billion a year earlier .",
#  'Dealers said the share was largely hit by investor disappointment about a refining margin of just 9.48 usd per barrel for the quarter and the performance of its shipping unit , which saw EBIT drop to 5 mln eur from 20 mln eur a year amid a fall in volumes and tanker rates .',
#  "` It is a testament to the quality of our LTE solution and our commitment to the Japanese market ' , he added .",
#  "The companies ' aim is to finalize the negotiations and sign the contracts at the start of October 2008 .",
#  'Metso Foundries Jyvaskyla Oy will discontinue production on this line by 30 September 2008 , the company said .',
#  "A total six of the polled analysts rated M-real -- two gave `` buy '' - `` accumulate '' , three gave `` hold '' and only one gave `` sell '' .",
#  'In September 2010 , the Finnish group agreed to buy Danish company Rose Poultry A-S for up to EUR23 .9 m in a combination of cash and stock .',
#  '$YANG Double bottom 5.2',
#  'Tesco share price down as grocer faces SFO investigation outcome',
#  '$aapl news is becoming very bullish again http://stks.co/tMU',
#  'GS Engineering will install the valves at a liquefied natural gas LNG plant it has built for UAE LNG extraction and gas plants operator GASCO in Ruwais , UAE .',
#  'The percentages of shares and voting rights have been calculated in proportion to the total number of shares registered with the Trade Register and the total number of voting rights related to them .',
#  "M-Real said there are ` no grounds ' for the rumors , which ` have been circulating in the market for some months . '",
#  'Lember said the matter was topical also in Estonia , where a bill has been drafted at the Social Affairs Ministry that would scrap old-age pensions on favorable conditions .',
#  "- Moody 's said it gave P A1 long-term senior unsecured and P P-1 short-term debt ratings to Finnish lender Aktia Bank 's EUR1bn USD1 .4 bn euro medium-term note EMTN program of 25 March 2011 .",
#  '$TSLA recall',
#  "The liquidity providing was interrupted on May 11 , 2007 when Aspocomp Group Oyj 's shares traded below 0.50 cent ( Aspocomp 's stock exchange release 11.5.2007 ) ."]

# %% [markdown]
# ### Random Word Deletion

# %%
class RandomWordDeletion(BaseEstimator, TransformerMixin):

    def __init__(self, num_duplicates, num_deletions):
        """ 
        Arguments
        ---------
        num_duplicates: int
            how many time we duplicate dataset
        num_deletions: int
            num of token to delete
        """
        self.num_duplicates = num_duplicates
        self.num_deletions = num_deletions

    def fit(self, X, y):
        return self

    def transform(self, documents, labels):
        # 1. duplicate documents
        documents, labels = list(documents), list(labels)
        duplicate_docs = [ sentence for i in range(self.num_duplicates) 
                for sentence in documents]
        duplicate_labels = [ label for i in range(self.num_duplicates) 
                for label in labels]

        # 2. perform word deletion
        new_docs = []
        for sentence, label in zip(duplicate_docs, duplicate_labels):
            words = sentence.split(' ')
            num_words_removed = 0
            while words and num_words_removed < self.num_deletions:
                # remove random index
                index_to_remove = random.randrange(len(words))
                words.pop(index_to_remove)
                num_words_removed += 1
            new_sentence = " ".join(words)
            if new_sentence: # make sure that sentence is at least one word 
                new_docs.append([new_sentence, label])

        return new_docs

# %%
word_del = RandomWordDeletion(2, 4)
word_del.transform(df['Sentence'], df['Sentiment'])
# Out:
# [["The GeoSolutions technology will leverage 's GPS solutions by providing Based Search Technology , a Communities Platform , relevant multimedia content and a new and powerful commercial model",
#   'positive'],
#  ['$ESI lows, down $2.50 a real possibility', 'negative'],
#  ["For the last quarter 2010 , Componenta 's net sales doubled EUR131m from EUR76m for the a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .",
#   'positive'],
#  ['According to the Finnish-Russian of Commerce , all the major construction companies of Finland are .',
#   'neutral'],
#  ['The Swedish buyout has sold its remaining 22.4 percent , almost eighteen months after taking the public Finland .',
#   'neutral'],
#  ["wouldn't surprised to green close", 'positive'],
#  ['$70 Billion Deal Skepticism', 'negative'],
#  ['SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANGE RELEASE 14 2008 AT 2:45 The Company updates its full year outlook and estimates its results to remain at for the full year .',
#   'negative'],
#  ["'s net sales rose by some 14 % year-on-year in the first nine .",
#   'positive'],
#  ["The Stockmann department store will have a total floor space of over 8,000 square metres Stockmann 's investment in project will have a of about EUR 12 million .",
#   'neutral'],
#  ['Circulation revenue has by % in Finland 4 in Sweden in 2008 .', 'positive'],
#  ['$SAP Q1 disappoints #software licenses Real problem? #Cloud trails $MSFT $ORCL $CRM $ADBE https://t.co/jNDphllzq5',
#   'negative'],
#  ['The subdivision made revenues last year of EUR 480.7 million EUR 414.9 million in 2008 , operating profits of EUR EUR 7.4 million .',
#   'positive'],
#  ['Line some .', 'neutral'],
#  ['Corporation STOCK EXCHANGE ANNOUNCEMENT 7.2.2007 at 10.30 A total of 56,955 new shares of Ahlstrom Corporation subscribed with option rights under the company stock option programs I 2001 and II 2001 .',
#   'neutral'],
#  ['$FB', 'positive'],
#  ['$MSFT SQL Server revenue double-digit with SQL Server revenue over 30%',
#   'positive'],
#  ["According to L+ñnnen 's CEO Matti Karppinen , the company to deliver fish products to its customers a day earlier it currently does",
#   'neutral'],
#  ["'s is quoted on OMX Helsinki Rautaruukki Oyj : RTRKS .", 'neutral'],
#  ['Elcoteq SE listed on the Nasdaq Helsinki', 'neutral'],
#  ['Two of these contracts for turntable anode vibrocompactors that will be to Hualu Co Ltd and another unnamed costumer .',
#   'neutral'],
#  ['Aviva, Friends Life top of billion pound', 'positive'],
#  ['In stead of being based on a , as is usual , the Teho energy is with fresh water .',
#   'neutral'],
#  ["The plans to increase unit 's specialist to several dozen -- on the market situation during 2010 .",
#   'neutral'],
#  ['The closed last with a turnover of million euros .', 'neutral'],
#  ['drive to get Baxalta board talking', 'positive'],
#  ['Costco: A Premier https://t.co/Fa5cnh2t0t', 'positive'],
#  ['five-storey , eco-efficient building gross floor area of about 15,000 sq m. It will also include apartments .',
#   'neutral'],
#  ['The first installment of Cinema Series concludes with a profile of Finnish inventor Olavi , whose personal artistic journey and at Fiskars has led to of design awards .',
#   'neutral'],
#  ['', 'neutral'],
#  ["Stockmann and Swedish sector company AB Lindex into an agreement on September 30 , 2007 , whereby Stockmann , a wholly-owned subsidiary of it , will make a tender offer for all Lindex 's issued shares .",
#   'positive'],
#  ["HUHTAMAKI OYJ STOCK EXCHANGE RELEASE , 16.9.2008 AT 13.32 Huhtamaki 's Markets for institutional investors and analysts is held in Espoo , 16 , 2008 starting 13.30 pm Finnish time .",
#   'neutral'],
#  ['`` We pleased welcome Noma into group .', 'positive'],
#  ['Profit before was EUR 105.9 .', 'neutral'],
#  ['Royal Dutch Shell to Buy for Nearly', 'positive'],
#  ['tm is not a press release service , no compensation for news , opinions or distributions .',
#   'neutral'],
#  ['ASSA ABLOY Bank a ` neutral recommendation and a share target of 174 crowns $ 24.7 - 19 euro on Swedish lock maker Assa Abloy AB .',
#   'neutral'],
#  ['The item included restructuring of EUR1 .6 m , while a year earlier EUR13 .1 m. Diluted EPS stood at EUR0 .3 versus a loss per share of 0.1 .',
#   'positive'],
#  ['2005 the bank posted a net of Lt mn', 'neutral'],
#  ['$AAPL afternoon selloff will brutal. get ready to lose a ton money.',
#   'negative'],
#  ['$TSLA recalling pretty much every single model X @cnnbrk got to short work you jump money trade',
#   'negative'],
#  ["Dolce & Gabbana has the European Union to declare Corporation Unikko '' floral pattern trademark invalid , in a continuing dispute between the two companies .",
#   'negative'],
#  ['InterContinental global room lags', 'negative'],
#  ['According to Finnish pension insurance company Varma , Varma was recipient of over two of the revenue of the earnings-related pension cover that competitive tendering in Finland .',
#   'positive'],
#  ['A portion , $ 12.5 million , will be recorded as part of its winnings in a prior patent Finnish Nokia Oyj .',
#   'positive'],
#  ['paying price for cut during crisis, chief', 'negative'],
#  ['The volume of investments in two phases of the project is estimated at USD 300mn ( EUR 215.03',
#   'neutral'],
#  ["Russia accounted for 9 % of magazine division 's revenue , EUR 114.40 mn ( USD 148.11 mn ) in 2009 , the USA for 18 % .",
#   'neutral'],
#  ['The also the already carried out investments to lead to an increase in its net sales 2010 from 2009 when they reached EUR 141.7 million',
#   'positive'],
#  ['Profit of the period was .', 'neutral'],
#  ['six breweries recorded a 5.2 percent growth in beer sales last year to million liters , from 256.88 million liters sold 2005 .',
#   'positive'],
#  ["In August-October , the company 's result before taxes totalled EUR 9.6 mn , EUR 0.5 mn in the corresponding in 2009 .",
#   'positive'],
#  ["'s project resources will be strengthened , director Paul Skogberg said .",
#   'positive'],
#  ['jumps Q3 sales top estimates', 'positive'],
#  ['The .', 'neutral'],
#  ['price logs has clearly improved from 2009 also price of pulpwood has gone up .',
#   'positive'],
#  ['Thus , SysOpen Digia , in accordance with Chapter 14 21 of the Finnish Companies Act 29.9.1978 - 734 obtained to all the shares of Sentera that are to be redeemed .',
#   'neutral'],
#  ['Diluted per share ( EPS ) fell to EUR 0.63 1.71', 'neutral'],
#  ['At 3:37 p.m. Eastern , a of 2,400 contracts changed hands at price of $ 0.45 .',
#   'neutral'],
#  ['of the most recent technology deliveries include refinery technology to Anrak Aluminium , an iron ore pelletizing to Tata Steel iron ore sintering plants to Steel .',
#   'neutral'],
#  ['$VIPS similar pattern like of May. sell? Same now..will go up much higher after this',
#   'positive'],
#  ['firm sales 187 mln eur in .', 'neutral'],
#  ['Enso has also had meetings with the labor authorities , Employment and Development Centres representatives of the in order to find solutions .',
#   'neutral'],
#  ['AstraZeneca of stalwarts fade', 'negative'],
#  ['RT @andrewnyquist Chartology: Yahoo: http://stks.co/1itr  looking chart, but nearing breakout',
#   'positive'],
#  ['Most bullish stocks on Twitter during $YHOO $GDX $GOOGL $STZ $GOLD $EW $VZ $CELG $SBUX more:',
#   'positive'],
#  ['Finnish GeoSentric decreased to EUR 939,000 in 2009 .', 'negative'],
#  ['Cohen & Inc. 5 534 shares representing 4.985 % of the share capital and voting rights .',
#   'neutral'],
#  ['More staff has been recruited Japan to further complement its network of to 50 service in more than 20 countries .',
#   'positive'],
#  ['Paper were negative territories , with Stora Enso R shedding 1.62 pct to 12.73 eur , UPM-Kymmene down 0.80 pct at 18.64 eur and M-real B 0.18 pct at 5.57 eur',
#   'neutral'],
#  ["Kauko-Telko 's centralized administration will be dissolved and appropriate parts will be transferred to operating activities Group by the end of the year .",
#   'neutral'],
#  ['Operating profit for quarter 2006 amounted to .2 on sales of EUR3 .62 bn .',
#   'neutral'],
#  ['chose the to attract consumers in the 25-45 age group to its Atria Fresh range of microwaveable',
#   'neutral'],
#  ['Finnish IT solutions provider Affecto Oyj HEL : AFE1V said its to a net loss of EUR 115,000 USD 152,000 in the second quarter 2010 from a profit of EUR 845,000 in the corresponding period year earlier .',
#   'neutral'],
#  ['US put plans in', 'negative'],
#  ['Profit for period was EUR 10.9 , down from EUR 14.3 2009 .', 'neutral'],
#  ['Profit for period was EUR , up from 1.3 mn .', 'positive'],
#  ['fell to EUR 20.3 mn EUR 74.2 mn in the second quarter 2008 .', 'neutral'],
#  [', sales returned growth in 2010 , CEO Pekka Eloholma .', 'positive'],
#  ['Operating totaled EUR 18.6 or 8.3 % sales .', 'neutral'],
#  ['Changes in the market situation tougher price competition have substantially reduced demand for bread manufactured at the Kauhava plant to the company .',
#   'negative'],
#  ['In connection with the deal , Digia will 19 persons Nokia in Oslo and Silicon in the USA .',
#   'neutral'],
#  ['The Brazilian unit of Finnish solutions provider F-Secure signed up 1,500 new clients last year , online news source Web quoted the division commercial director , Vladimir Brand+úo , as .',
#   'positive'],
#  ["The fair value of company 's investment properties went down EUR 2.768 billion at the end of 2009 from EUR billion a year .",
#   'neutral'],
#  ['Dealers said the share was largely hit by investor disappointment about a refining margin of just 9.48 usd barrel for the quarter and the performance of its shipping , which saw EBIT drop to 5 mln eur from 20 mln eur a year amid a in volumes and tanker .',
#   'negative'],
#  ["` is a to quality our LTE solution and our commitment to the Japanese market ' , he added .",
#   'neutral'],
#  ["The companies ' aim is finalize the negotiations and sign the contracts at the of 2008",
#   'neutral'],
#  ['Metso Foundries Jyvaskyla will discontinue production on this line by September 2008 , the company',
#   'neutral'],
#  ["A total six of the polled analysts M-real -- two `` buy '' - `` accumulate , three gave `` '' and only one gave `` sell '' .",
#   'neutral'],
#  ['In September 2010 , the agreed to buy company Rose Poultry A-S for up EUR23 .9 m in a combination of cash and stock .',
#   'positive'],
#  ['', 'positive'],
#  ['Tesco share down grocer faces investigation', 'negative'],
#  ['$aapl news bullish http://stks.co/tMU', 'positive'],
#  ['GS Engineering the valves a liquefied natural gas LNG plant has built for UAE LNG extraction and gas plants operator GASCO in Ruwais , UAE .',
#   'neutral'],
#  ['The percentages of shares and voting rights have been in proportion to the number of shares registered the Trade Register and the total number voting rights related to them .',
#   'neutral'],
#  ["said there are ` no ' for the , which ` have been circulating in the market for months . '",
#   'neutral'],
#  ['said the matter was topical also in Estonia , where a been drafted at the Social Affairs Ministry that would scrap old-age on favorable conditions .',
#   'neutral'],
#  ["- Moody 's said gave A1 long-term senior unsecured and P P-1 short-term debt ratings to Finnish lender Aktia 's EUR1bn USD1 .4 bn euro medium-term EMTN program of 25 March 2011 .",
#   'neutral'],
#  ['', 'negative'],
#  ["The liquidity providing was interrupted on May , when Aspocomp Group Oyj 's shares traded below 0.50 cent Aspocomp 's stock exchange release 11.5.2007 )",
#   'neutral'],
#  ['The will leverage Benefon GPS solutions by providing Location Based Search Technology , Communities Platform , location relevant multimedia content and a new and powerful commercial model .',
#   'positive'],
#  ['lows, down to $2.50 BK real possibility', 'negative'],
#  ["For the last of 2010 , Componenta 's net sales doubled EUR131m from EUR76m for the same period a earlier , while it moved to a zero pre-tax profit from a pre-tax of EUR7m .",
#   'positive'],
#  ['According to the Finnish-Russian Chamber of Commerce , the companies Finland are operating in Russia .',
#   'neutral'],
#  ['The Swedish buyout firm has sold its remaining percent stake , almost eighteen months after taking the public .',
#   'neutral'],
#  ['be surprised to see green', 'positive'],
#  ['BG Deal Meets Shareholder', 'negative'],
#  ['SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANGE RELEASE 14 , 2008 2:45 PM The Company its full year outlook and estimates results to remain at loss for the full year .',
#   'negative'],
#  ["'s net sales by 14 % year-on-year in the first nine months 2008 .",
#   'positive'],
#  ["Stockmann department will have a total floor space of over 8,000 square and Stockmann 's investment in the project will have a tag of about EUR 12 million .",
#   'neutral'],
#  ['Circulation has increased by 5 % in 4 % in in 2008 .', 'positive'],
#  ['$SAP Q1 disappoints down. problem? #Cloud growth trails $MSFT $ORCL $GOOG $CRM $ADBE https://t.co/jNDphllzq5',
#   'negative'],
#  ['The subdivision made sales revenues last year of EUR 480.7 million EUR million in 2008 , operating profits 44.5 million EUR 7.4 million .',
#   'positive'],
#  ['Viking services .', 'neutral'],
#  ["Ahlstrom Corporation STOCK EXCHANGE 7.2.2007 at 10.30 total of 56,955 new shares of Ahlstrom Corporation have been subscribed with rights under the company 's stock programs I 2001 and II 2001 .",
#   'neutral'],
#  ['gone', 'positive'],
#  ['$MSFT SQL Server revenue grew double-digit SQL Premium revenue over 30%',
#   'positive'],
#  ["L+ñnnen Tehtaat 's CEO Matti Karppinen , company aims to deliver fish products to its customers a day earlier than it does .",
#   'neutral'],
#  ["The company 's share is on NASDAQ OMX Helsinki Rautaruukki RTRKS",
#   'neutral'],
#  ['Elcoteq SE is the Nasdaq Helsinki Ltd.', 'neutral'],
#  ['of these contracts are for turntable anode vibrocompactors that will be delivered Gansu Hualu Co and another unnamed costumer .',
#   'neutral'],
#  ['Friends Life top forecasts of 5.6 pound', 'positive'],
#  ['In stead of being based on a drink , as , the Teho energy drink is made with water .',
#   'neutral'],
#  ["The company plans to increase the 's specialist to several dozen -- depending on market during 2010 .",
#   'neutral'],
#  ['company closed last a turnover of four million euros .', 'neutral'],
#  ['CEO drive to Baxalta board talking', 'positive'],
#  ['Costco: Dividend Play https://t.co/Fa5cnh2t0t', 'positive'],
#  ['The five-storey , eco-efficient building have a floor of 15,000 sq m. It will also include apartments .',
#   'neutral'],
#  ['The first installment of the Cinema Series concludes with a profile of Finnish inventor Olavi Linden , whose personal artistic journey and at has led to dozens of awards',
#   'neutral'],
#  ['', 'neutral'],
#  ["Stockmann and Swedish sector company AB Lindex entered into an agreement on 30 , 2007 , whereby Stockmann , or a wholly-owned subsidiary of it , will make a tender for all of Lindex 's shares .",
#   'positive'],
#  ["HUHTAMAKI OYJ EXCHANGE RELEASE , 16.9.2008 Huhtamaki 's Capital Markets Day for institutional investors and analysts is held in Espoo , September 16 , 2008 starting at 13.30 pm Finnish time",
#   'neutral'],
#  ['`` We are welcome Noma into Cramo group', 'positive'],
#  ['- was EUR 82.7 million .', 'neutral'],
#  ['Royal Dutch BG Group for Nearly $70', 'positive'],
#  ['tm is not a press release service receives no compensation its news , opinions or distributions .',
#   'neutral'],
#  ["ASSA ABLOY Kaupthing Bank gave a ` neutral ' and a share price target of 174 crowns $ 24.7 19 euro on Swedish maker Assa Abloy AB",
#   'neutral'],
#  ['The item included restructuring costs of EUR1 .6 m , a year earlier were .1 m. Diluted EPS stood at EUR0 .3 versus a loss per share of 0.1 .',
#   'positive'],
#  ['In 2005 the posted a profit of Lt 8.2', 'neutral'],
#  ['$AAPL afternoon as usual will brutal. get to lose a ton of', 'negative'],
#  ['$TSLA pretty much X @cnnbrk got to short that even at work you jump in money trade',
#   'negative'],
#  ["Dolce & Gabbana the European Union to declare Marimekko Corporation 's `` Unikko '' floral pattern trademark invalid in a continuing between the two companies .",
#   'negative'],
#  ['InterContinental Hotels revenue estimates', 'negative'],
#  ['According to Finnish pension insurance company , Varma was the recipient of over two thirds of the of the earnings-related pension cover that under competitive tendering in .',
#   'positive'],
#  ['A portion , $ 12.5 million , will be recorded as part of its winnings a prior dispute with Finnish phone maker Oyj',
#   'positive'],
#  ['still paying price dividend crisis, chief says', 'negative'],
#  ['The volume of investments in the two phases the project is at USD 300mn ( EUR 215.03 .',
#   'neutral'],
#  ["Russia accounted for 9 % of Lagardere magazine 's revenue , or EUR 114.40 mn 148.11 mn ) in 2009 , the USA - for 18 % .",
#   'neutral'],
#  ['also estimates the already out investments to lead to an increase in its net sales for 2010 from 2009 when they reached 141.7 million .',
#   'positive'],
#  ['Profit of accounting period EUR mn', 'neutral'],
#  ['The six breweries recorded a 5.2 growth domestic beer sales last year to 270.21 million , from 256.88 million liters sold 2005 .',
#   'positive'],
#  ["In August-October 2010 the company 's result before taxes EUR 9.6 mn , up from EUR 0.5 mn the corresponding period 2009 .",
#   'positive'],
#  ["'s sales project resources will also be strengthened director Paul said .",
#   'positive'],
#  ['Tesco price Q3 top estimates', 'positive'],
#  ['print .', 'neutral'],
#  ['The for logs has clearly improved from and the price pulpwood has gone up .',
#   'positive'],
#  ['Thus , SysOpen Digia has in with Chapter Section 21 of the Finnish Companies Act 29.9.1978 - , obtained title to all the shares of Sentera that are to be redeemed .',
#   'neutral'],
#  ['Diluted per share EPS ) fell EUR 0.63 from 1.71 .', 'neutral'],
#  ['At p.m. Eastern time , block of 2,400 contracts hands at a bid price of $ .',
#   'neutral'],
#  ['Some of the most recent technology deliveries include refinery technology to Anrak , an iron ore pelletizing plant to Tata Steel iron ore plants to Bhushan Steel',
#   'neutral'],
#  ['similar pattern of May. Did u Same now..will go up much higher after this drop.',
#   'positive'],
#  ['The generated of mln eur 2005 .', 'neutral'],
#  ['Stora has had meetings with the labor authorities , Employment Development Centres and representatives of the government in order to find solutions .',
#   'neutral'],
#  ['down as of stalwarts', 'negative'],
#  ['RT @andrewnyquist Yahoo: http://stks.co/1itr Crazy looking chart, nearing breakout resistance line...',
#   'positive'],
#  ['Most bullish on Twitter during this dip. $YHOO $GOOGL $STZ $EW $VZ $CELG $SBUX $SCTY https://t.co/iuZJelfwt3',
#   'positive'],
#  ["Finnish GeoSentric 's net sales to 939,000 in .", 'negative'],
#  ['Cohen & Steers , Inc. : 626 shares representing 4.985 % of share capital voting rights .',
#   'neutral'],
#  ['More been recruited in Japan to further complement its network of close to 50 service locations in than 20 countries worldwide',
#   'positive'],
#  ['Paper companies were in territories , with Stora Enso R shedding 1.62 pct to 12.73 eur UPM-Kymmene down 0.80 pct at 18.64 eur and M-real pct lower at 5.57 eur .',
#   'neutral'],
#  ["Kauko-Telko 's centralized administration will be dissolved and appropriate parts of will transferred to operating activities and Group by end of the year .",
#   'neutral'],
#  ['Operating profit for the quarter April-June 2006 amounted to EUR182 .2 m sales .62 .',
#   'neutral'],
#  ['chose the DeLight to attract consumers in the 25-45 group to its Atria range of microwaveable .',
#   'neutral'],
#  ['Finnish IT solutions provider Oyj HEL : AFE1V today its slipped to a net loss of EUR 115,000 USD 152,000 in the second quarter of 2010 from profit of 845,000 in the corresponding period a year earlier .',
#   'neutral'],
#  ['US Gazprom-Shell alliance jeopardy', 'negative'],
#  ['for period was EUR 10.9 mn , down EUR 14.3 mn in .', 'neutral'],
#  ['for the was mn , up from EUR 1.3 mn .', 'positive'],
#  ['profit fell to EUR 20.3 mn from EUR mn second quarter of 2008 .',
#   'neutral'],
#  ['However sales returned to in April-June 2010 CEO Pekka Eloholma .',
#   'positive'],
#  ['Operating profit totaled 18.6 mn % of net sales', 'neutral'],
#  ['Changes in the market situation and tougher price competition have substantially demand for bread packaging manufactured at plant according to the company .',
#   'negative'],
#  ['In connection with the deal will employ 19 from Nokia in Oslo and in Silicon in the USA .',
#   'neutral'],
#  ['The Brazilian unit of Finnish security solutions provider F-Secure signed up 1,500 new clients last year , online news Reseller Web quoted division commercial , Vladimir Brand+úo , as saying .',
#   'positive'],
#  ["The value of the company 's investment properties went down to EUR 2.768 billion at end of 2009 EUR 2.916 billion a earlier .",
#   'neutral'],
#  ['Dealers said the share was largely hit investor disappointment about a margin of just 9.48 usd for the quarter and the performance of its shipping unit , which saw EBIT drop to 5 mln eur from 20 mln eur a year amid a fall in volumes and tanker rates .',
#   'negative'],
#  ["It a testament to the quality of our LTE solution and our commitment the Japanese ' , he added .",
#   'neutral'],
#  ["The ' aim is to the negotiations and sign the at start of October 2008 .",
#   'neutral'],
#  ['Metso Jyvaskyla Oy will production on line by 30 September , the company said .',
#   'neutral'],
#  ["A six of the polled rated M-real -- two `` buy '' - `` accumulate , three gave `` hold '' and only one gave `` sell '' .",
#   'neutral'],
#  ['In September 2010 the group agreed to buy Danish company Rose Poultry A-S for up EUR23 m in a combination of cash and stock .',
#   'positive'],
#  ['', 'positive'],
#  ['share price down as SFO outcome', 'negative'],
#  ['news is very bullish', 'positive'],
#  ['GS will install the valves at a liquefied natural gas LNG plant it has built for UAE LNG extraction and gas plants operator GASCO in Ruwais',
#   'neutral'],
#  ['The of shares and voting rights have been calculated in proportion to the total number of shares with the Trade and the total number of voting rights related them .',
#   'neutral'],
#  ["M-Real said there are no grounds ' for the rumors , which ` been in the for some months . '",
#   'neutral'],
#  ['said the matter was also in Estonia , where a bill has been drafted at the Social Affairs Ministry that would scrap old-age favorable conditions .',
#   'neutral'],
#  ["- Moody 's said it P A1 long-term senior unsecured and P-1 short-term debt ratings to Finnish lender Aktia 's EUR1bn USD1 .4 bn euro medium-term note program of 25 March 2011 .",
#   'neutral'],
#  ['', 'negative'],
#  ["The providing was interrupted on May 11 , 2007 when Aspocomp Group Oyj 's shares traded below cent ( Aspocomp 's stock exchange release )",
#   'neutral']]

# %% [markdown]
# ### Character Deletion

# %%
class RandomCharacterDeletion(BaseEstimator, TransformerMixin):

    def __init__(self, num_duplicates, num_deletions):
        """ 
        Arguments
        ---------
        num_duplicates: int
            how many time we duplicate dataset
        num_deletions: int
            num of token to delete
        """
        self.num_duplicates = num_duplicates
        self.num_deletions = num_deletions

    def fit(self, X):
        return self

    def transform(self, documents, labels):
        # 1. duplicate documents
        documents, labels = list(documents), list(labels)
        duplicate_docs = [ sentence for i in range(self.num_duplicates) 
                for sentence in documents]
        duplicate_labels = [ label for i in range(self.num_duplicates) 
                for label in labels]

        # 2. perform character deletion
        new_docs = []
        for sentence, label in zip(duplicate_docs, duplicate_labels):
            characters = [c for c in sentence]
            num_char_removed = 0
            while words and num_char_removed < self.num_deletions:
                # remove random index
                index_to_remove = random.randrange(len(characters))
                characters.pop(index_to_remove)
                num_char_removed += 1
            new_sentence = "".join(characters)
            if new_sentence: # make sure that sentence is at least one word 
                new_docs.append([new_sentence, label])

        return new_docs

# %%
char_del = RandomCharacterDeletion(2, 5)
char_del.transform(df['Sentence'], df['Sentiment'])
# Out:
# [["The GeoSolutions technology will leverage Benefon ' GPS solutions by providing Location Based Seach Technoogy , a Communities Platform ,location relevant multimedia content and a new and powerful ommercial model .",
#   'positive'],
#  ['ESI on lws, down $150to $250 BK a real possibility', 'negative'],
#  ["Fr the last quarer of 2010 , omponenta 's net sales doubled to EUR131m from EUR76m fo the same period a year earlier , while it moved to a zero pe-tax profit from a pre-tax loss of EUR7m .",
#   'positive'],
#  ['Accordig to th Finish-Russian Chaber of Commerce , all the major construction companies of Finland ar operating in Russia .',
#   'neutral'],
#  ['The Swedish buyot firm has sod its reaining 22.4 percent stake, almost eighten months after taking the company public in Finland .',
#   'neutral'],
#  ["$SPY wouldn'tbe surprised to ee a green os", 'positive'],
#  ["Shell's $70 Billio G Deal eets Shareholder Spticism", 'negative'],
#  ['SSH COMMUNCATIONS SECURITY CORP STOCK EXCHANGE RELEASE OCTOBER 14 , 2008 AT 2:45 M The Company updates its full year oulok and estimates its results to remain at loss for th full year .',
#   'negative'],
#  ["Kone 's net sales rose by some 14 %yea-on-ya in the first nine month of 2008 .",
#   'positive'],
#  ["The Stockmann departmnt storewill have a total floor space of over 8,000 square metres and Stockmann 's investment in the project will have a pricetg of about EUR 12 millio .",
#   'neutral'],
#  ['Circlation revenue has incresed by 5 % in Finland nd 4 % in Sedenin 2008 .',
#   'positive'],
#  ['$SAP Q1 diappoints as #software liceses down. Real problem? #Cloud growth trils $MST $ORCL $GOOG $CRM $ADBE htts://t.co/jNDphllzq5',
#   'negative'],
#  ['e subdivision made sales revenues last yea of EUR 480. million EUR 414.9 million in 2008 , and operating profits of EUR 44.5 million EUR 7.4million .',
#   'positive'],
#  ['Viing Line has caneledsomeservices ', 'neutral'],
#  ["Ahlstrom Corporation STOCK EXCHANGE ANUNCEMENT .2.2007 at 10.30 A total of 56,955 new shares of Ahlstrom Corporation have been ubscribed with option rights under the company 's stock option rograms I 2001 and II 2001 .",
#   'neutral'],
#  ['FB e gren on day', 'positive'],
#  ['MSFT SQL Seer revenue grew double-digit with SQL Server Preium revenue growing over 30%http://stks.co/ir2F',
#   'positive'],
#  ["Accordng to L+ñnen Tehtaat 's CEO Matti Karppinen , t company aims to deliver fish produts to its customers a day earlier than it currently does .",
#   'neutral'],
#  ["The compan 's share is quoted on NASDAQ OMX Helsiki Rautarukki Oyj :RTRKS ",
#   'neutral'],
#  ['Elcote SEis listed on the Nasda OMX Helsinki Lt..', 'neutral'],
#  ['Two of these contracts are for turntable anodevibrocompactors that will e delivere to GansuHualu Aluminum Co Ltd and another unnamd costumer .',
#   'neutral'],
#  ['Aviva, Friend Life top forecasts ahead of 5.6 billio poun mrge',
#   'positive'],
#  ['In stead of being based on a soft drink ,as is sual , the Tho energy drink is ade wih fresh water .',
#   'neutral'],
#  ["The company plans o inrease the unit 's specialist staff to everal dozen -- depndig on the market situation during 2010 .",
#   'neutral'],
#  ['The company close last year with a tunover of about fou mllioneuros .',
#   'neutral'],
#  ['hir CE seps up drive to get Baxalta board talkng', 'positive'],
#  ['Costco: A Premier Retai ividend lay https:t.co/Fa5cnh2t0t $COST',
#   'positive'],
#  ['The five-story , eco-effcient uilding will have a goss floor area of about 15,000 sq m. Itwill also include apartments .',
#   'neutral'],
#  ['The first installment of the Cinema Sries concludes with  profile of Finnish inventor lavi Linden , whose personal artisti journey and work at Fiskars has led todozens of design awards .',
#   'neutral'],
#  ['All re wlcm.', 'neutral'],
#  ["Stockmann and Swedish sector compan  Lindex entered into an agreement on September 30 , 2007 , whereby Stockmann , or a wholly-owned subsidiary of i , wil make a public tender offer for all of Lindex 's issued shares .",
#   'positive'],
#  ["HUHTAMAKI OYJ STOCK EXCHANGE RELEASE , 16.9.2008 AT 3.32 Huhtamaki 's Capital Markets Day or institutional investorsand analysts is held in Espoo , September16 , 2008 starting at 13.30 pm Finnish tme .",
#   'neutral'],
#  ['`` eare plesed to welcome apeksNoma into Cramo group .', 'positive'],
#  ['- Profi beforetaes was EUR105.9 82.7 million ', 'neutral'],
#  ['RoalDutch Shel to uy BG Group for Nearly 70 Billion', 'positive'],
#  ['inancialWre tm is not a press release service  ad receives no compensation for its news , opinionsor distributions .',
#   'neutral'],
#  ["ASSA ABLOY Kaupthing Bank gave a ` neutral ' rcommendaion and a share prie target of 174 rowns $ 24.7 - 1 euro on Swedish lock maker Assa Abloy AB .",
#   'neutral'],
#  ['The item included restructuring cost of EUR1 .6 m , while a year arler they were EUR13 .1 m.Diluted EPS stood at EUR0 .3 versus a loss per share of UR 0.1 .',
#   'positive'],
#  ['n 005 the ban posted a nt rofit of Lt 8.2 mn .', 'neutral'],
#  ['AAPL fternoon selloff as usualwill be brutal. get ready to losea ton of moey.',
#   'negative'],
#  ['$TSLA recalling pretty much every singe model X @cnnrk got to sort that evenat work you ump in money trade',
#   'negative'],
#  ["Dolce & Gabbana has askedthe European Unon to declare Marimekko Corporation 's `` Unikko '' floral pattern trademark invalid , in acontinuing dispute between the two compaie .",
#   'negative'],
#  ['InterContinental Hoels first-quarter globalroo revenue lgs estimaes',
#   'negative'],
#  ['According to Finnish pensin insurance comany Varma , Varma was the recipient of over two tirds of the revenue of the earnings-related pension cover that was under competitive tendering in inand .',
#   'positive'],
#  ['A portion ,  12.5 millin , willbe recorded as part of its winnings in a prior patent dispute wth Finnish phone maker Noki Oyj .',
#   'positive'],
#  ['L&G sill paying rice for diviend cut during risis, hief says', 'negative'],
#  ['The volumeo investments in the two phases of te project is etimated at USD 300mn ( EUR 215.03 m ) .',
#   'neutral'],
#  ["Russa accounted for 9 % of th Lagadere magazine division 's revenue , or EUR 114.40 mn  USD 148.11mn ) in 2009 , the USA - for 18 % .",
#   'neutral'],
#  ['The company ao estimates the already carried out investments toled to an increase inits net sales for 2010 from 2009 when they reached EUR 141.7 million .',
#   'positive'],
#  ['Profit o the accouning period was UR 0.3mn.', 'neutral'],
#  ['The six breweries recorded a 5.2 percnt groth in domestic beer sales last yar to 270.21 million lites , from 256.88 million liters sold i 2005 .',
#   'positive'],
#  ["In Auust-October 2010 , the company 's resul beore taxes totalled EUR 9.6 mn , up from EUR 0.5 mn in he correspondig period in 2009 .",
#   'positive'],
#  ["Syteemitiimi 's salesad project resourcs will also be strengthened , directorPaul Skogberg said .",
#   'positive'],
#  ['Tesco shre prce jumps as Q3 sales tpetimates', 'positive'],
#  ['Th n print is here.', 'neutral'],
#  ['The price for logshas clearly improved fro 2009 and also thepric of pulpwod has gone up .',
#   'positive'],
#  ['Thus , SysOpen Digia hs , in accordance with Chapter 14 Section 21 of the Finnish Companie Act 29.9.1978  734 , obtained title to all the shares of Sentera thatar to be redeemed .',
#   'neutral'],
#  ['Diluted eanings er share ( EPS ) fll to EUR 0.63 rom EUR 1.71.', 'neutral'],
#  ['At :37 p.m. Eastern time , a block of 2400 contracts changed hads at a id price of $ 0.5 .',
#   'neutral'],
#  ['Some of the most recent technology deliveries include refinery technology to AnrakAluminium , an iron or pelletizing lant to TataSteel and iron ore sintering plants to BhushanSteel .',
#   'neutral'],
#  ['$VIPS similar pattern like beginningof Ma. Did u sell? Sae now..will go up much higer after this dop.',
#   'positive'],
#  ['The fim generatd sales of 17 mln eur in 005.', 'neutral'],
#  ['Stora Enso has also ha meetings with thelabor authorities , Employment and Economic Developmen Centres and rpresentatives of the government in order to findsolutions .',
#   'neutral'],
#  ['AstraZeneca profit down assaes f stalwrts fae', 'negative'],
#  ['RT @andrewnyquist Chartology: Yahoo: http:sts.co/1itr $YHOO  Crzy looking chart, but nearing breakout resistace line...',
#   'positive'],
#  ['ost bullh stocks on Twitter during this dip. $YHOO $GX $GOOGL $STZ $GOLD $EW $VZ$CELG $SBUX $SCTY more: https://t.co/iuZJelfwt3',
#   'positive'],
#  ["FinnishGeoSentric 's nt sales ecreased to EUR 939,000 n January-Marh 2009 .",
#   'negative'],
#  ['Cohen & Steers , Inc. :  534 626 shares repesenting 4.985 % of he share capital and vting righs .',
#   'neutral'],
#  ['More staff has been recruited in Japan to further complement it network o clse to 50 serice locations in more than 20countries worldwide .',
#   'positive'],
#  ['Paper companies were in negative teritorie , wih Stora Enso R shedding 1.62 pc to 12.73 eur , UPM-Kymene down 0.80 pct at 18.64 eur and M-real B 0.18 pct lower at 5.57 eur .',
#   'neutral'],
#  ["Kauko-elko 's centralized administration will be dissolved and appropriate parts ofit will be transferred to operating activities and Group aministration by the end oftheyear .",
#   'neutral'],
#  ['Oprating rofit for the quarer April-June 200 aounted to EUR182 .2 m on sales of EUR3 .62 bn .',
#   'neutral'],
#  ['Atria chose the DeLight to atract cnsumers in the 25-45 age grou to its Atria Fresh rage of mcrowaveable meals .',
#   'neutral'],
#  ['Finnish T solutions provider Affecto Oyj HEL : AFE1V said today its slipped to a net loss of EUR 11,000 USD 152,000 in the second quarter of 2010 from a prfit of EUR 845,000 in te correspondin period a year earlier .',
#   'neutral'],
#  ['US santions put azprom-Sell allianc plas in jeopardy', 'negative'],
#  ['Prot for the period was ER 10.9 mn , down from EUR14.3 mnin 2009 .',
#   'neutral'],
#  ['rofit for te peiod was EUR 5.9 mn , up froEUR 1.3 mn .', 'positive'],
#  ['Operating profitfell to EU 20.3 mnfrom EUR 74.2 mn in the scond qarter of 2008 .',
#   'neutral'],
#  ['However , sales eturned to gowt in pril-June 2010 , CEO Pekka Eloholm said .',
#   'positive'],
#  ['Operating profit totald ER18.6 m o 8.3 % of net sales .', 'neutral'],
#  ['Changes in the market situation and tougher price competition have substntially reduce demand for bread packaging manufactured at the Kahava plant ,according to the company.',
#   'negative'],
#  ['I connection with the eal , Digia will employ9 persons from Nokia in Oslo and in Silicon Valleyin the USA .',
#   'neutral'],
#  ["The Brazilian unit of Finish securit solutions provider F-Secure signed up 1,500 new cients last year , online news source Reseller Web quoted the division 's commerial direcor , Vladimir Brand+úo , as saying .",
#   'positive'],
#  ["The fair value of the compny 's investment poperties went down to EUR .768 illion atthe end of 2009 from EUR 2.916 billion a year earlier .",
#   'neutral'],
#  ['Dealers said the share was largely hit by investor disappointment about a refining margin of just 9.48usd per barrel for the quarter and the performance of its shiping unit , which saw EBIT drop to 5 mln eur fro 20 mln eur a year amid a fll in volumes an tanker rates .',
#   'negative'],
#  ["` It is a testament to he quality of ur LTE soltion and our commitment to he Japaese market ' , he added .",
#   'neutral'],
#  ["The companies ' aimis to fialize the negotiations and sign the contracts at testart o October 2008 .",
#   'neutral'],
#  ['Metso Foundries Jyvaskyla O wil disotinue prduction on this line by 30 September 2008 , the company said .',
#   'neutral'],
#  ["A toal six of the polled analyss rated -real -- two gave `` buy '' - `` accumulate '' , three gve `` hold '' and only one gave `` ell '' .",
#   'neutral'],
#  ['In September 2010 , the Finnish grou agreed to buy Danish company Rose Poultry AS for up to EUR23 .9 m i a combinatio of csh and stock .',
#   'positive'],
#  ['$YANG ouble bot .2', 'positive'],
#  ['Tesco share price dow as gocer faces SFO investigatin utcme', 'negative'],
#  ['$aapl ewsi becoming vry bullish again http://stks.o/tMU', 'positive'],
#  ['GS Engineering will istall the valves at a liquefied natural gas LNG plant it has built forUAE LNG extracon and gas plants opeator GASCO in Ruwais , UAE .',
#   'neutral'],
#  ['The percentages of shares and voting rights have been calculated in proportion to the total numbe of shares registered with the Trad Register and the tota number of vting rights relatedto them .',
#   'neutral'],
#  ["M-Real saidther are ` no grounds ' for the ruors , which ` have been circulating in the maret fo some months . '",
#   'neutral'],
#  ['Lember said the matter wa topical also in Estonia , where a bill has been drafted at the Social Affairs inistry tat wold scrap old-age pnsions on favorable conditions .',
#   'neutral'],
#  ["- Moody 's said it gave P A1 long-term senior unsecured and P P-1 short-term debt raings to Finnish lender Aktia Bnk 's EUR1bn USD1 .4 bn euro dium-term note EMTN program of 25 Marc 2011 .",
#   'neutral'],
#  ['SL eall', 'negative'],
#  ["The liquidity proidin was interrupted on May 11 , 2007 whenAspocomp Group Oyj 's shares traded below 050 cent ( Aspocomp 's stock exchange release 1.5.2007 ) .",
#   'neutral'],
#  ["The GoSolutions technology will leverag Benefon 's GPS solutions by providing Locatio Based Sarch Technology , a Communities Platform , location relevant multimedia content and a new and powerfulcommercial model .",
#   'positive'],
#  ['$ES on lowsdon $1.50 to $2.50 BK a ral possibility', 'negative'],
#  ["For the last quarterof 2010 , Componenta 's net sale doubled toEUR131m from EUR76m for the same period a year earlier , while i moved to a zer pre-tax profit from a pre-tax loss of EUR7m .",
#   'positive'],
#  ['According to the FinnishRussian Chamber of Comerce  all the major construction comanis of Finland are operating in Russia .',
#   'neutral'],
#  ['he Swedish buyout firm has sold its remaining 22.4 percent stake , almost eighteen monts after taking te ompany public i Finland .',
#   'neutral'],
#  ["$SPY wouldn' b surrised to see a gren clos", 'positive'],
#  ["Shell's $0 Billion BG Deal Meet Shrholde Skepticism", 'negative'],
#  ['SSH COMMUNICATIONS SECURITY CORP STOCK XCHANGERELEASE OCTOBER 14 , 008 AT 2:45 M The Company updates its full yea outlook and estimates its results to remain at loss for the full year .',
#   'negative'],
#  ["Kone 's net sales rose by some 14 % year-on-year in the fir ninemoths f 2008 .",
#   'positive'],
#  ["The Stockmann department store will have a total floo space of over 8,000 square metres and Stockmann 's investmnt in the project will have a pice g of about EUR 12 million .",
#   'neutral'],
#  ['Circulaton revenue ha increased by % in Finland and 4 % i Sweden in 2008 .',
#   'positive'],
#  ['$SAP Q1 disappoints as #software licensesdown. Real problem? #Coud gowthtrails $MSFT $ORCL $GOOG $CRM $ADBEhttps://t.co/jNDphllzq5',
#   'negative'],
#  ['The subdiviion made sales revenues last year of EUR 480.7 million EUR 414.9 milion in 2008 , and operting profits of EUR 44.5 millionEUR 7.4 milion .',
#   'positive'],
#  ['Vikig Lnehas cancele some service .', 'neutral'],
#  ["Ahstrom Corporation STOCK EXCHANG ANNUNCEMNT 7.2.2007 at 10.30 A total of 56,955 new shares of Ahlstrom Corporation have been subscribed with option rights under he company 's stock option programs I 2001 and II 2001 .",
#   'neutral'],
#  ['$F go geen on ay', 'positive'],
#  ['$MSFT SQL Server revenue grew doul-digit with SQL Server Pemium revenue growing over 30 http://stks.c/ir2F',
#   'positive'],
#  ["ccording to L+ñnnen Tehtaat 's CEO Matti Karppinen  the company aims o deliver fish proucts to its customers a day earlier than it currently des .",
#   'neutral'],
#  ["Th ompany 's share is quoted on NASDAQ OMX Helsini Rutaruukki Oyj :RTRKS .",
#   'neutral'],
#  ['Elcoeq SE is listed on th Nasda OMX Helsinki td .', 'neutral'],
#  ['Two of these contracts are for turtable anode vibrocomactors that will be delivered to Gansu Hualu Aluminum o Ltd ad another unnamed ostumer .',
#   'neutral'],
#  ['Aviva, riends Lfe top forecasts aead of 5.6 billin poundmerger',
#   'positive'],
#  ['In stead of being based on a soft drik , as is usual , the Teho enery drn s made with fresh water .',
#   'neutral'],
#  ["The ompany plans to increase the unit 's specialist staff to several dozen -- ependng on the arket siuation during 2010 .",
#   'neutral'],
#  ['The company closed lat year with a turover of aot four million euro .',
#   'neutral'],
#  ['Shire CEO steps updriveto get Baxltaboard taling', 'positive'],
#  ['Costco: A Preme Retai Dividend Play htts://t.co/a5cnh2t0t $COST',
#   'positive'],
#  ['The five-storey , eo-efficiet building will have a gross floor area of aout 15,000 sm. It will also include apartments .',
#   'neutral'],
#  ['The first installment of the Cinema Series concludes with a profil of Finnih inventor Oavi Linden , whose personal artistic journey and work at Fiskar has led todozens of design awards .',
#   'neutral'],
#  ['l ae elcome ', 'neutral'],
#  ["Stockmann d Swedish sector compay AB Lindex entered into an agreement on September 30 , 2007 , whereby Stockmann , o a wholly-wned subsidiary of it , will make a public tender offer for all of Lindex 's issued shares .",
#   'positive'],
#  ["HUHTAMAKI OYJ STOCK EXCHANGE RELEASE , 16.9.208 AT 13.32 Huhtamaki 's Capital Markets Day for institutional investors and analysts is held in Espoo Septebe 16 , 2008 starting at 13.30 pm Finnish time .",
#   'neutral'],
#  ['`` We are pleased to welcome Tapeks Noma itCramo grp .', 'positive'],
#  ['- rofit before taxes was EUR 10.9 82.7 milin.', 'neutral'],
#  ['Royal DuthShell to BuyBG Group for Nearly $70 Bilin', 'positive'],
#  ['FinancialWire tm is not a press release service , and receivs no compensation for it news , opnins or distributios .',
#   'neutral'],
#  ["ASSA ABLOY Kpthing Bank gave a ` neutral ' recommendation and a share prie targt of 174 crowns $ 24.7 - 19 euro on Swedish lock mker Assa Abloy AB .",
#   'neutral'],
#  ['The item included restructring costs ofEUR1 .6 m , while ayear earlier they were EUR13 .1 m. Diluted EPS stood at UR0 .3 versus a loss per share of UR 0.1 .',
#   'positive'],
#  ['In2005 te bank posted a net profit f t 8.2 mn.', 'neutral'],
#  ['$AAPL afternoon selloff as usual wil be butal. et read to loe a ton of money.',
#   'negative'],
#  ['$TSLA realling pretty much every single model X @cnnbrk ot to short hat ven at work yu jump in money trade',
#   'negative'],
#  ["Dolce & Gabbana hs asked the European Union to declare MarimekkoCorportion 's `` Unikko '' floral pattern trademark invalid , in a continung dispute beween the two companies .",
#   'negative'],
#  ['IntrContinenta Hotelsfirstquarter global room revenue lgs estimates',
#   'negative'],
#  ['According to Finish pension insurancecompany Varma , Varma was therecipient of ver two thirs of the revenue of the earnings-related pension cover that was under competitive tendering in Finland .',
#   'positive'],
#  ['A portion , $ 12.5 million , will be recorded as part of is winings in a priorpatnt dispute wit Finnish phone maker Nokia Oyj .',
#   'positive'],
#  ['&G still pying price for dividend cut during crisi, chif sys', 'negative'],
#  ['The volume of ivetents in the two phases of the project is estimad at USD 300mn ( EUR 215.03 mn ) .',
#   'neutral'],
#  ['Russia accounted for 9 % of the Lagardere magzine division s revenue , or EUR 114.40 mn ( US 14.11 mn ) in 2009 , the USA - for 18% .',
#   'neutral'],
#  ['Thecompany also estimates the already carried out investmets to lead o an increase in its net sales for 2010 from 2009 whenthey reached EUR 141.7 milion .',
#   'positive'],
#  ['Profit of he accuntin eriod wa EUR 0.3 mn .', 'neutral'],
#  ['The six breweies recorded a .2 percent growth indomestic beer sales last year to270.21 illion liters , from 256.88 million liters sold in 2005 .',
#   'positive'],
#  ["InAugust-October 2010 , thecompany 's result beforetaxes totaled EUR 9.6 mn , up from EUR 0.5 mn in the coresponding period in 2009 .",
#   'positive'],
#  ["Systemitiimi 's sales nd project resources will also be strngtened , dirctor Paul Skogberg said .",
#   'positive'],
#  ['Teo share prce jumps as Q sales top estimtes', 'positive'],
#  ['Thefine prit i re .', 'neutral'],
#  ['The pric for logs has clearly improved from 2009 and also the prie of ulpwood has goe p .',
#   'positive'],
#  ['Thu , SysOpen Digiahas , in accordanc with Chapter 14 Section 21 of the Finnish Companies Act 29.9.1978 - 734 , obtained title to all the shares of Sentera tat ae to be redeemed .',
#   'neutral'],
#  ['Diuted earings er share ( EPS ) ell to EUR 0.3 from EUR 1.71 .', 'neutral'],
#  ['At 3:37 p.m Eastern time , a block of2,400 contacts changed hands at a bd price of $ 045 .',
#   'neutral'],
#  ['Some of the most recent technology deliveries include refinery technology t Anak Aluminium , an iron oepelletizing plant to Tata Steel and iron ore sintering plats to Bhushan Steel .',
#   'neutral'],
#  ['$IPS simlar pattern like beginning of May. id u sell? Same now..will go up muchhigher afte this drop.',
#   'positive'],
#  ['The irm generated sales of 17 ml eu in 2005 ', 'neutral'],
#  ['Stora Enso has also had meetings with the laborauthorities , Employment and Economic Development Centres and representative of the government in orde to fi solutions .',
#   'neutral'],
#  ['AstraZeneprofit down as sles ofstalwarts fade', 'negative'],
#  ['RT @andrewnyquis Chartology: Yahoo: ttp://stks.co/1itr $YHOO Crazy looking chart, but nearingbreakot resistance line...',
#   'positive'],
#  ['Most bulish stocks on Twiter during thi dip. $YHOO $GX $GOOGL $STZ $GOLD $EW $V $CELG $SBUX $SCTY more: https://t.co/iuZJelfwt3',
#   'positive'],
#  ["Fnis GeoSentric 's net sals decreased to EUR 939,000 in January-March 200 .",
#   'negative'],
#  ['Cohen  Steers , Inc. : 5 534 26 shares epresenting 4.985  of the share capitl and voting rights .',
#   'neutral'],
#  ['More staff has been recruitedin Japan to further complement its network of clos to 50 service locatins in more thn 20 countries worldwid .',
#   'positive'],
#  ['Paper compaies were in negative terrtories , with Stora Enso R shedding1.62 pct to 12.73 er , UPM-Kymmene down 0.80 pct at 18.64 eur and Mreal B 0.18 pct lower at 5.57 eur .',
#   'neutral'],
#  ["Kauko-Telko 's centralized administration will be dissolved and appropriate parts of it wil betransferred t operating actiities and Group administration by th end of the year .",
#   'neutral'],
#  ['Operatin profit o the uarter April-June 2006 amounted to EUR182 .2 mon sales of EUR3 .62 bn .',
#   'neutral'],
#  ['Atria chse the DeLight to attract consumers in the 25-45 age group titsAtria Fresh range of microwaveable meals.',
#   'neutral'],
#  ['Finnish IT solutions povider Affecto Oyj HEL : AFE1V said today ts slipped to a net loss ofEUR 115,000 USD 152,000 in he second quarter of 2010 from a profit of EUR 845,000 in thecorresponding period a year earlier .',
#   'neutral'],
#  ['US actions pu Gazprom-Shell alliancplans in jeopardy', 'negative'],
#  ['Profit for the peiod was ER 10.9 mn , down from UR 14.3mn in 2009.',
#   'neutral'],
#  ['Pofit for the period was EUR 5.9 m , up fom EU .3 mn .', 'positive'],
#  ['Operating profit fell o EUR 20.3 m fro EUR 74.2 mn in the second quarter f 200 .',
#   'neutral'],
#  ['Howeer , sles returnd to growth i April-June 010 , CEO Pekka Eloholma said .',
#   'positive'],
#  ['Operating profit otaled EUR 18.6 mnr8.3 % ofnet sales .', 'neutral'],
#  ['Changes in the marketsituatio and tougher prce competition have subsantially reduced demand for bread packagin manufactured at the Kauhava plant , according to the company .',
#   'negative'],
#  ['In connection wihthe deal , Diia will employ 19 persons from Nokia in Oslo and in Silicon Valley in thUSA .',
#   'neutral'],
#  ["The Brazilian unit o Finnish security solutions provider F-Secure signed up 1,500 new clients last year , nline news source Reseller Web quoted the division 's commercial irecor , Vladimir Brand+úo , a saying .",
#   'positive'],
#  ["The fair vle of th company 's investment properties went downt EUR 2.768 billion at the end of 2009 from EUR 2.916 billion a year earlier .",
#   'neutral'],
#  ['Dealers said the share was largely hit by investor diappointment about a refining margin of just 9.48 usd per brrelfor the quarter and the performance of its shipping unit , which saw EBIT drop to 5 mln eur from 20 mln eur  ear amid a fall in volumes and tanker rates .',
#   'negative'],
#  ["` I is a tesament to the quality of our LTE solution andor commitment to th Japanese market ' , he added .",
#   'neutral'],
#  ["The companies ' am is t finalize the negotiations nd sgn the contracts at the star of October 2008 .",
#   'neutral'],
#  ['Meto Foundies Jyvaskyla Oy will discontinue roduction on this lin by 30 September 200 , the company said .',
#   'neutral'],
#  ["A total six of the olled analysts rated M-real -- two gave `` buy '' - `` accumulate '' , three gave `` hld '' nd only one gave ``sell ' .",
#   'neutral'],
#  ['In September 2010 , the Finish groupagreed to bu Danish company Rose Pultry A-S for up to EUR23 .9 m in a combination of cashand stock .',
#   'positive'],
#  ['$YN Doub bottm 5.2', 'positive'],
#  ['esco share price down as grocer faces SFOinvestigion outcme', 'negative'],
#  ['$aapl new is becoming very bullish aan http:/stks.co/tU', 'positive'],
#  ['GS Engineering will instal the valves a a liquefied naural gas LNG plant it has built for UAE LNG extraction and gas plants operato GASCO in Ruwais , UE .',
#   'neutral'],
#  ['The percntages of shares and voting rights have been calculated in proportionto the total number of shares registered with the Trade Register ad the total numberof voting rights rlated to them .',
#   'neutral'],
#  ["M-Real said tere are ` no grounds ' fr the rumors , which ` hae been circulatng in the market for ome months . '",
#   'neutral'],
#  ['Lember sad the matter wastopica also in Estonia  where a bill has been drafted at he Social Affairs Ministry that would scrap old-age pensions on favorable conditions .',
#   'neutral'],
#  ["- Moody s said it gave P A1 long-term senio unsecured and P P-1 short-term dbt ratings o Finnish lender Aktia Bank 's EUR1bn USD1 .4 bn euro mediumterm note EMTN program of 25 March 2011 .",
#   'neutral'],
#  ['$TSLeal', 'negative'],
#  ["The liquidity povidingwas interrupted on May 11 , 2007 when Aspocomp Group Oyj s shares traded below 0.0 cent ( Aspocomp ' stock exchange release 11.5.2007 ) .",
#   'neutral']]

# %% [markdown]
# ### Word Swap

# %%
class RandomWordSwap(BaseEstimator, TransformerMixin):

    def __init__(self, num_duplicates, num_swaps):
        """ 
        Arguments
        ---------
        num_duplicates: int
            how many time we duplicate dataset
        num_swaps: int
            num of token to swap
        """
        self.num_duplicates = num_duplicates
        self.num_swaps = num_swaps

    def fit(self, X, y):
        return self

    def transform(self, documents, labels):
        # 1. duplicate documents
        documents, labels = list(documents), list(labels)
        duplicate_docs = [ sentence for i in range(self.num_duplicates) 
                for sentence in documents]
        duplicate_labels = [ label for i in range(self.num_duplicates) 
                for label in labels]

        new_docs = []
        # 2. perform word swap
        for sentence, label in zip(duplicate_docs, duplicate_labels):
            new_sentence = self._swap_words_in_sentence(sentence)
            new_docs.append([new_sentence, label])

        return new_docs

    def _swap_words_in_sentence(self, sentence):
        """ 
        Given a sentence (string), return a new sentence where words were 
        swap n times
        """
        words = sentence.split(' ')
        for _ in range(self.num_swaps):
            # generate random index swap
            index = random.randrange(len(words) - 1)
            words[index], words[index + 1] = words[index + 1], words[index]
        return " ".join(words)

# %%
word_swap = RandomWordSwap(2, 3)
word_swap.transform(df['Sentence'], df['Sentiment'])
# Out:
# [["The GeoSolutions technology leverage will 's Benefon GPS solutions by providing Location Based Search , Technology a Communities Platform , location relevant multimedia content and a new and powerful commercial model .",
#   'positive'],
#  ['on $ESI lows, $1.50 down to $2.50 BK a possibility real', 'negative'],
#  ["For the last quarter of 2010 , Componenta 's net sales to doubled EUR131m from EUR76m the for same period a year earlier , while it moved to a pre-tax zero profit from a pre-tax loss of EUR7m .",
#   'positive'],
#  ['According to the Chamber Finnish-Russian Commerce of , all the major construction of companies Finland are operating in Russia .',
#   'neutral'],
#  ['The Swedish buyout firm has sold its remaining 22.4 percent stake , almost eighteen after months taking the public in company Finland .',
#   'neutral'],
#  ["wouldn't $SPY be surprised to a see close green", 'positive'],
#  ["$70 Shell's BG Billion Meets Deal Shareholder Skepticism", 'negative'],
#  ['SSH COMMUNICATIONS CORP SECURITY STOCK EXCHANGE RELEASE OCTOBER 14 , 2008 AT 2:45 PM The Company updates its full year outlook estimates and its results to remain at loss for the full . year',
#   'negative'],
#  ["Kone 's net sales rose by some % 14 year-on-year in the first nine months of 2008 .",
#   'positive'],
#  ["The Stockmann department store will have a total floor space of over 8,000 square metres Stockmann and 's investment in the project will have a price tag of about EUR 12 million .",
#   'neutral'],
#  ['Circulation revenue has 5 increased by % in Finland and 4 in % Sweden in 2008 .',
#   'positive'],
#  ['$SAP Q1 disappoints as #software licenses down. Real problem? #Cloud trails growth $MSFT $ORCL $GOOG $CRM $ADBE https://t.co/jNDphllzq5',
#   'negative'],
#  ['The subdivision made sales last revenues of year EUR 480.7 million EUR 414.9 million in 2008 , and operating profits of 44.5 EUR million EUR 7.4 million .',
#   'positive'],
#  ['Viking Line canceled has some services .', 'neutral'],
#  ["Ahlstrom Corporation STOCK EXCHANGE ANNOUNCEMENT 7.2.2007 at 10.30 A total of 56,955 new shares Ahlstrom of Corporation have been subscribed with option rights under the company 's stock option programs I 2001 and II 2001 .",
#   'neutral'],
#  ['gone $FB green on day', 'positive'],
#  ['$MSFT SQL Server revenue double-digit grew SQL with Server Premium revenue growing 30% over http://stks.co/ir2F',
#   'positive'],
#  ["to According L+ñnnen 's Tehtaat CEO Matti Karppinen , the company aims to deliver fish products to its customers a day earlier than it does currently .",
#   'neutral'],
#  ["The company 's share is quoted NASDAQ on OMX Helsinki Rautaruukki Oyj : RTRKS .",
#   'neutral'],
#  ['Elcoteq is SE listed on Nasdaq the OMX Helsinki . Ltd.', 'neutral'],
#  ['Two of these contracts for are turntable anode vibrocompactors that will be delivered to Gansu Hualu Aluminum Co Ltd and another unnamed costumer .',
#   'neutral'],
#  ['Friends Aviva, Life forecasts top ahead 5.6 of billion pound merger',
#   'positive'],
#  ['In stead being based of on a soft drink , as is usual , the Teho energy drink is made with fresh . water',
#   'neutral'],
#  ["The company plans to increase the unit specialist 's staff to dozen -- several depending on the market situation during 2010 .",
#   'neutral'],
#  ['The closed company last year with a turnover of four about million . euros',
#   'neutral'],
#  ['Shire CEO steps drive up get to Baxalta talking board', 'positive'],
#  ['A Costco: Premier Retail Dividend https://t.co/Fa5cnh2t0t $COST Play',
#   'positive'],
#  ['The five-storey , eco-efficient building will a have area gross floor of about 15,000 sq m. It will also include apartments .',
#   'neutral'],
#  ['The first installment of the Cinema Series concludes with a profile of Finnish inventor Olavi , Linden whose personal artistic and journey work at Fiskars has led to of dozens design awards .',
#   'neutral'],
#  ['All are . welcome', 'neutral'],
#  ["Stockmann and Swedish company sector AB Lindex entered into an agreement on September 30 , 2007 , whereby Stockmann , or a wholly-owned subsidiary of will it , make a public tender offer for all of Lindex 's issued shares .",
#   'positive'],
#  ["HUHTAMAKI STOCK OYJ EXCHANGE RELEASE , 16.9.2008 AT 13.32 Huhtamaki 's Capital Markets Day for institutional investors and analysts is held in Espoo , September , 16 2008 starting at pm 13.30 Finnish time .",
#   'neutral'],
#  ['We `` pleased are to welcome Tapeks Noma into group Cramo .', 'positive'],
#  ['- Profit taxes before EUR was 105.9 82.7 . million', 'neutral'],
#  ['Royal Dutch Shell to Buy BG Group Nearly for $70 Billion', 'positive'],
#  ['tm FinancialWire is not a press release service , and receives no compensation its for , news opinions or distributions .',
#   'neutral'],
#  ["ASSA ABLOY Kaupthing Bank gave a ` neutral recommendation ' and a share target price of 174 crowns $ 24.7 - 19 euro on Swedish lock maker Assa AB Abloy .",
#   'neutral'],
#  ['The item included restructuring costs of EUR1 .6 m , while a year they earlier were EUR13 .1 m. Diluted EPS stood at .3 EUR0 versus a loss per share of EUR . 0.1',
#   'positive'],
#  ['In 2005 the bank a posted profit net of Lt 8.2 . mn', 'neutral'],
#  ['$AAPL afternoon selloff as be usual will brutal. get ready lose to a ton of money.',
#   'negative'],
#  ['$TSLA recalling pretty much every single model X got @cnnbrk short to that even at work you jump money in trade',
#   'negative'],
#  ["Dolce & Gabbana has asked the European Union declare to Marimekko Corporation 's Unikko `` '' floral pattern trademark invalid , in a continuing dispute the between two companies .",
#   'negative'],
#  ['InterContinental Hotels room global first-quarter revenue lags estimates',
#   'negative'],
#  ['According to Finnish pension insurance company Varma , Varma the was recipient of over two thirds of the revenue of the earnings-related pension cover that was competitive under in tendering Finland .',
#   'positive'],
#  ['A portion , 12.5 $ million , will be recorded as part of winnings its in a prior patent with dispute Finnish phone maker Nokia Oyj .',
#   'positive'],
#  ['L&G paying price still for cut dividend during crisis, chief says',
#   'negative'],
#  ['The volume of investments in the phases two the of project estimated is at USD 300mn ( EUR 215.03 mn ) .',
#   'neutral'],
#  ["Russia accounted for 9 % of the Lagardere division magazine 's revenue or , EUR 114.40 mn ( USD 148.11 mn ) in 2009 , the USA - for 18 . %",
#   'neutral'],
#  ['The company also the estimates already carried out investments to lead to an increase in net its for sales 2010 from 2009 when they reached EUR 141.7 million .',
#   'positive'],
#  ['of Profit the accounting EUR period was 0.3 mn .', 'neutral'],
#  ['The six breweries recorded a 5.2 percent growth in beer domestic sales last year to 270.21 million liters , from 256.88 million liters sold in 2005 .',
#   'positive'],
#  ["In August-October 2010 , the company 's result before taxes totalled EUR 9.6 , mn up from EUR 0.5 mn the corresponding in period in 2009 .",
#   'positive'],
#  ["Systeemitiimi sales 's and project resources will be also , strengthened director Paul Skogberg said .",
#   'positive'],
#  ['jumps Tesco share price as Q3 sales top estimates', 'positive'],
#  ['The fine print here is .', 'neutral'],
#  ['price The logs for has clearly improved from 2009 also and the price of pulpwood has gone up .',
#   'positive'],
#  ['Thus , SysOpen Digia has in , accordance with Chapter 14 Section 21 of the Finnish Companies Act 29.9.1978 - 734 obtained , title to all the shares of Sentera that are to be . redeemed',
#   'neutral'],
#  ['Diluted earnings per ( share EPS ) fell to 0.63 EUR from EUR . 1.71',
#   'neutral'],
#  ['At p.m. 3:37 time Eastern a , block of 2,400 contracts changed hands at a bid price of $ 0.45 .',
#   'neutral'],
#  ['Some of the most recent technology deliveries refinery include technology to Anrak Aluminium , an iron ore pelletizing plant to Tata Steel and iron sintering ore plants to Steel Bhushan .',
#   'neutral'],
#  ['$VIPS similar pattern like beginning of May. Did u sell? Same now..will go up much after higher this drop.',
#   'positive'],
#  ['The firm generated 187 sales of eur mln in 2005 .', 'neutral'],
#  ['Enso Stora has also had with meetings the labor authorities , Employment and Economic Development Centres and representatives of the in government order to find solutions .',
#   'neutral'],
#  ['AstraZeneca down profit of as sales stalwarts fade', 'negative'],
#  ['RT @andrewnyquist Chartology: http://stks.co/1itr Yahoo: $YHOO  Crazy looking chart, but nearing breakout resistance line...',
#   'positive'],
#  ['Most bullish stocks on Twitter this during dip. $YHOO $GDX $GOOGL $STZ $EW $GOLD $VZ $CELG $SBUX $SCTY https://t.co/iuZJelfwt3 more:',
#   'positive'],
#  ["Finnish GeoSentric 's net sales decreased to EUR 939,000 in January-March . 2009",
#   'negative'],
#  ['Cohen & , Steers Inc. : 5 534 626 shares representing 4.985 % of capital the share and voting rights .',
#   'neutral'],
#  ['More staff has been in recruited Japan to further complement its network of close to 50 service in locations more 20 than countries worldwide .',
#   'positive'],
#  ['Paper companies were in negative territories with , Stora Enso R shedding 1.62 pct to 12.73 eur , UPM-Kymmene 0.80 down pct at 18.64 eur and M-real B 0.18 pct at lower 5.57 eur .',
#   'neutral'],
#  ["Kauko-Telko 's centralized administration will dissolved be and appropriate parts of it will be transferred to activities operating Group and administration by the end of the year .",
#   'neutral'],
#  ['Operating profit for the quarter April-June 2006 amounted to .2 EUR182 m on sales of .62 bn EUR3 .',
#   'neutral'],
#  ['Atria the chose DeLight attract to consumers in the 25-45 group age to its Atria Fresh range of microwaveable meals .',
#   'neutral'],
#  ['Finnish IT solutions provider Affecto Oyj HEL : AFE1V said today its slipped to a net loss of EUR 115,000 USD 152,000 in the second quarter of 2010 from profit of a EUR in 845,000 the corresponding period a year earlier .',
#   'neutral'],
#  ['US sanctions put Gazprom-Shell alliance plans jeopardy in', 'negative'],
#  ['Profit for the period was 10.9 EUR mn , down from mn EUR 14.3 in 2009 .',
#   'neutral'],
#  ['Profit the for period was EUR 5.9 mn , up from 1.3 mn EUR .', 'positive'],
#  ['Operating profit fell to 20.3 EUR mn from EUR 74.2 in mn the second of quarter 2008 .',
#   'neutral'],
#  ['However sales , returned to growth in April-June 2010 , CEO said Pekka Eloholma .',
#   'positive'],
#  ['Operating profit EUR totaled mn or 18.6 8.3 % of net sales .', 'neutral'],
#  ['Changes in the market situation and tougher have price competition substantially reduced demand for bread manufactured packaging at the Kauhava plant , according to the company .',
#   'negative'],
#  ['In connection with the deal , Digia will employ 19 from persons Nokia in Oslo and Silicon in Valley in the . USA',
#   'neutral'],
#  ["Brazilian The unit of Finnish security solutions provider F-Secure signed up 1,500 new clients last year , online news source Reseller Web quoted the division commercial 's director , Vladimir , Brand+úo as saying .",
#   'positive'],
#  ["The fair value the of company 's investment properties went down to 2.768 EUR billion at the end of 2009 EUR from 2.916 billion a year earlier .",
#   'neutral'],
#  ['Dealers said the share was largely hit investor by disappointment about a refining margin of just 9.48 usd per barrel for the quarter and the performance of its shipping unit , which saw EBIT drop to 5 mln eur from 20 mln eur a year a amid fall in and volumes tanker rates .',
#   'negative'],
#  ["` It is a to testament the quality our of solution LTE and our commitment to the Japanese market ' , he added .",
#   'neutral'],
#  ["' The companies aim to is finalize the negotiations and sign the contracts at the start of October 2008 .",
#   'neutral'],
#  ['Jyvaskyla Metso Foundries Oy will discontinue production this on line by 30 September 2008 , the company said .',
#   'neutral'],
#  ["A total six of the polled rated analysts -- M-real two `` gave buy '' - `` accumulate '' , three gave `` hold '' and only one gave `` sell '' .",
#   'neutral'],
#  ['In , September 2010 the Finnish group agreed to buy Danish company Rose Poultry A-S for up to .9 EUR23 m in a combination of cash and stock .',
#   'positive'],
#  ['Double 5.2 $YANG bottom', 'positive'],
#  ['share Tesco price down as grocer faces SFO investigation outcome',
#   'negative'],
#  ['$aapl news is becoming very bullish http://stks.co/tMU again', 'positive'],
#  ['GS Engineering will install the valves at a liquefied natural gas LNG it has plant built for UAE LNG extraction and gas plants operator GASCO in Ruwais UAE , .',
#   'neutral'],
#  ['The percentages of shares and voting have rights been calculated in proportion to the total number shares of registered with the Trade Register and the number total of voting rights related to them .',
#   'neutral'],
#  ["M-Real said there are ` no grounds ' for the rumors , which ` have circulating been in the market for some months . '",
#   'neutral'],
#  ['said Lember the matter was topical also in Estonia , where a has bill been drafted at the Social Affairs Ministry that would scrap old-age pensions on conditions favorable .',
#   'neutral'],
#  ["- Moody 's said it gave P A1 long-term senior and unsecured P P-1 short-term debt ratings to Finnish lender Aktia Bank 's EUR1bn USD1 .4 bn euro medium-term note EMTN program of 2011 25 March .",
#   'neutral'],
#  ['recall $TSLA', 'negative'],
#  ["The liquidity providing was interrupted on May 11 , 2007 when Aspocomp Group Oyj 's shares traded below 0.50 ( cent Aspocomp 's exchange stock release ) 11.5.2007 .",
#   'neutral'],
#  ["The GeoSolutions technology will leverage Benefon 's solutions GPS by Location providing Based Search Technology , a Communities Platform , location relevant multimedia content and a new and powerful model commercial .",
#   'positive'],
#  ['$ESI on down lows, $1.50 $2.50 to a BK real possibility', 'negative'],
#  ["the For last quarter of 2010 , Componenta 's sales net doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of . EUR7m",
#   'positive'],
#  ['According to the Finnish-Russian Chamber of Commerce all , major the construction companies of Finland are in operating Russia .',
#   'neutral'],
#  ['The Swedish buyout firm sold has remaining its 22.4 percent stake , almost eighteen months after taking the company public Finland in .',
#   'neutral'],
#  ["$SPY wouldn't be surprised a to green see close", 'positive'],
#  ["$70 Shell's BG Billion Deal Meets Skepticism Shareholder", 'negative'],
#  ['SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANGE RELEASE OCTOBER 14 , 2008 AT 2:45 PM The updates Company its full year outlook and estimates its results to at remain loss the for full year .',
#   'negative'],
#  ["Kone 's net sales rose some by 14 % in year-on-year first the nine months of 2008 .",
#   'positive'],
#  ["The Stockmann department store will have a total space floor of over 8,000 metres square and Stockmann 's investment in the project will a have price tag of about EUR 12 million .",
#   'neutral'],
#  ['Circulation revenue has increased by % 5 in Finland 4 and % in Sweden in . 2008',
#   'positive'],
#  ['$SAP Q1 disappoints as #software licenses down. Real #Cloud problem? growth trails $ORCL $MSFT $GOOG $ADBE $CRM https://t.co/jNDphllzq5',
#   'negative'],
#  ['The subdivision made sales revenues last of year EUR 480.7 million EUR 414.9 million in 2008 , and operating profits EUR of 44.5 EUR million 7.4 million .',
#   'positive'],
#  ['Viking has Line canceled some services .', 'neutral'],
#  ["Ahlstrom Corporation STOCK EXCHANGE 7.2.2007 ANNOUNCEMENT at 10.30 A total of 56,955 shares new of Ahlstrom Corporation have been subscribed with option rights under the company 's stock option programs I and 2001 II 2001 .",
#   'neutral'],
#  ['gone $FB on day green', 'positive'],
#  ['SQL $MSFT Server grew revenue double-digit with SQL Server Premium revenue growing 30% over http://stks.co/ir2F',
#   'positive'],
#  ["According to L+ñnnen Tehtaat 's CEO Matti Karppinen , the company aims to deliver fish products customers its to a day earlier than it currently does .",
#   'neutral'],
#  ["company The 's share is quoted on NASDAQ Helsinki OMX Rautaruukki : Oyj RTRKS .",
#   'neutral'],
#  ['SE Elcoteq is listed on Nasdaq the Helsinki OMX Ltd. .', 'neutral'],
#  ['Two of these contracts are for anode turntable vibrocompactors that will be delivered to Hualu Gansu Aluminum Co Ltd and another costumer unnamed .',
#   'neutral'],
#  ['Aviva, Friends Life top ahead forecasts of billion pound 5.6 merger',
#   'positive'],
#  ['In of stead being on based soft a drink , as is usual , the Teho energy drink is made with fresh water .',
#   'neutral'],
#  ["The company to plans increase the unit specialist 's staff to several dozen -- depending on the situation market during 2010 .",
#   'neutral'],
#  ['The company last closed year with a turnover of about four euros . million',
#   'neutral'],
#  ['CEO steps Shire up drive to get Baxalta talking board', 'positive'],
#  ['A Costco: Premier Retail Dividend https://t.co/Fa5cnh2t0t $COST Play',
#   'positive'],
#  ['five-storey The , eco-efficient building will have gross a floor area of about 15,000 sq m. It will also include . apartments',
#   'neutral'],
#  ['The first installment of the Cinema concludes Series with a profile of Finnish inventor Olavi Linden , whose personal artistic journey and work at Fiskars has led to of design dozens awards .',
#   'neutral'],
#  ['All are . welcome', 'neutral'],
#  ["Stockmann and Swedish sector company Lindex AB entered into an agreement on September 30 , 2007 , whereby Stockmann , or a subsidiary wholly-owned of it , will make a public offer tender for all of Lindex 's issued shares .",
#   'positive'],
#  ["HUHTAMAKI OYJ STOCK EXCHANGE RELEASE , 16.9.2008 AT 13.32 's Huhtamaki Capital Markets Day for institutional investors analysts and is held Espoo in , September 16 , 2008 starting at 13.30 pm Finnish time .",
#   'neutral'],
#  ['`` We are to pleased welcome Tapeks into Cramo Noma group .', 'positive'],
#  ['- Profit before taxes was 105.9 EUR 82.7 million .', 'neutral'],
#  ['Dutch Royal Shell to Buy BG Group $70 for Nearly Billion', 'positive'],
#  ['tm FinancialWire is not press a release service , and receives no compensation for its news , opinions distributions or .',
#   'neutral'],
#  ["ASSA ABLOY Kaupthing gave Bank a ` neutral ' recommendation and a share price target of 174 24.7 crowns $ - 19 euro on Swedish lock maker Assa Abloy AB .",
#   'neutral'],
#  ['The item included restructuring costs of EUR1 .6 m , a while year earlier they were EUR13 .1 m. Diluted at EPS stood EUR0 .3 versus a loss per share of EUR 0.1 .',
#   'positive'],
#  ['In 2005 bank the a posted net profit Lt of 8.2 mn .', 'neutral'],
#  ['$AAPL afternoon as selloff usual will brutal. get be ready to lose a ton of money.',
#   'negative'],
#  ['$TSLA recalling pretty much every single model X @cnnbrk to got short that at work even you jump in money trade',
#   'negative'],
#  ["Dolce & has Gabbana asked the European Union to declare Marimekko Corporation 's `` '' Unikko floral pattern trademark , invalid in a continuing dispute between the two companies .",
#   'negative'],
#  ['InterContinental global Hotels first-quarter room revenue estimates lags',
#   'negative'],
#  ['According to Finnish pension insurance company , Varma Varma was the recipient of over two thirds of the revenue of the earnings-related pension cover that was under competitive tendering in Finland .',
#   'positive'],
#  ['A portion , $ million 12.5 , be will recorded as part of winnings its in a prior patent dispute with Finnish phone maker Nokia Oyj .',
#   'positive'],
#  ['L&G still paying for price dividend during cut chief crisis, says',
#   'negative'],
#  ['The of volume investments in the two phases of the project is estimated at USD 300mn ( EUR 215.03 mn ) .',
#   'neutral'],
#  ["Russia accounted for 9 % of the Lagardere magazine division 's revenue or , EUR 114.40 mn ( USD 148.11 mn ) in 2009 USA , the - for 18 % .",
#   'neutral'],
#  ['The company estimates also the already carried out investments to lead to an increase in its net for 2010 sales from 2009 when they reached EUR 141.7 million .',
#   'positive'],
#  ['of Profit accounting the was period EUR 0.3 mn .', 'neutral'],
#  ['six The breweries recorded a 5.2 percent growth in domestic beer last sales to year 270.21 million liters , from 256.88 million liters sold in 2005 .',
#   'positive'],
#  ["In August-October 2010 , the 's company result before taxes totalled EUR mn 9.6 , up from EUR 0.5 mn in the corresponding in period 2009 .",
#   'positive'],
#  ["Systeemitiimi 's and sales project will resources also be strengthened director , Paul Skogberg said .",
#   'positive'],
#  ['share price Tesco jumps as sales Q3 top estimates', 'positive'],
#  ['The fine print is . here', 'neutral'],
#  ['price The for has logs clearly improved from 2009 and also the price of has pulpwood gone up .',
#   'positive'],
#  ['Thus , SysOpen Digia has , in accordance with Chapter 14 Section 21 of the Finnish Companies Act 29.9.1978 734 - , obtained title to all shares the of Sentera are that to be redeemed .',
#   'neutral'],
#  ['Diluted share earnings per ( EPS ) to fell EUR 0.63 from EUR 1.71 .',
#   'neutral'],
#  ['At 3:37 Eastern p.m. time , a block of 2,400 contracts hands changed at a bid price $ of 0.45 .',
#   'neutral'],
#  ['Some of the most recent technology deliveries include refinery to technology Anrak Aluminium , iron an ore pelletizing plant to Tata Steel iron and ore sintering plants to Bhushan Steel .',
#   'neutral'],
#  ['$VIPS similar pattern like beginning of May. Did sell? u Same now..will up go higher much after this drop.',
#   'positive'],
#  ['The firm generated sales of 187 in mln eur . 2005', 'neutral'],
#  ['Stora Enso has also had meetings with the labor , authorities Employment and Economic Development and Centres of representatives the government in order to find solutions .',
#   'neutral'],
#  ['AstraZeneca profit as down sales of stalwarts fade', 'negative'],
#  ['RT Chartology: @andrewnyquist Yahoo: $YHOO http://stks.co/1itr  Crazy looking but chart, nearing breakout resistance line...',
#   'positive'],
#  ['Most bullish stocks on Twitter during dip. this $GDX $YHOO $GOOGL $STZ $GOLD $EW $VZ $CELG $SBUX $SCTY https://t.co/iuZJelfwt3 more:',
#   'positive'],
#  ["GeoSentric Finnish 's sales net decreased to EUR in 939,000 January-March 2009 .",
#   'negative'],
#  ['Cohen & Steers , Inc. : 5 534 626 shares representing 4.985 % of the share and capital rights . voting',
#   'neutral'],
#  ['More staff has recruited been in Japan to further complement its of network close to 50 service locations more in than 20 countries worldwide .',
#   'positive'],
#  ['Paper companies were in negative territories , with Stora Enso R shedding 1.62 to pct 12.73 eur , UPM-Kymmene down 0.80 at pct 18.64 and eur M-real B 0.18 pct lower at 5.57 eur .',
#   'neutral'],
#  ["Kauko-Telko 's centralized administration will be appropriate dissolved and parts of it will transferred be to operating activities and Group administration by the end of the year .",
#   'neutral'],
#  ['Operating profit the quarter for April-June 2006 amounted to EUR182 m .2 on sales of EUR3 .62 bn .',
#   'neutral'],
#  ['Atria the chose DeLight to attract consumers in the age 25-45 group to its Fresh Atria range of microwaveable meals .',
#   'neutral'],
#  ['Finnish IT solutions provider Affecto Oyj HEL : AFE1V said today its slipped to a net loss of EUR 115,000 USD 152,000 in the second quarter of 2010 from a profit EUR of 845,000 in corresponding the period year a earlier .',
#   'neutral'],
#  ['US put sanctions Gazprom-Shell plans in alliance jeopardy', 'negative'],
#  ['Profit for the period was EUR 10.9 , mn down EUR 14.3 from mn in 2009 .',
#   'neutral'],
#  ['Profit for period the was EUR 5.9 mn , up EUR from mn 1.3 .', 'positive'],
#  ['Operating profit fell to 20.3 EUR mn from EUR 74.2 mn the in quarter second of 2008 .',
#   'neutral'],
#  ['However , sales returned growth to April-June in 2010 , Pekka CEO Eloholma said .',
#   'positive'],
#  ['Operating profit totaled EUR 18.6 mn % or 8.3 of sales net .', 'neutral'],
#  ['Changes in the market situation and tougher price competition have substantially reduced bread demand for packaging manufactured at Kauhava the plant , according to the company .',
#   'negative'],
#  ['In connection with the deal , Digia will employ 19 persons from Nokia Oslo and in in Silicon in Valley the USA .',
#   'neutral'],
#  ["The Brazilian unit of security Finnish solutions provider signed F-Secure up new 1,500 clients last year , online news source Reseller Web quoted the division 's commercial director , Vladimir Brand+úo , as saying .",
#   'positive'],
#  ["The fair of value the company 's investment properties went down to EUR 2.768 billion at the end of 2009 EUR from 2.916 a billion year earlier .",
#   'neutral'],
#  ['Dealers the said share was largely hit by investor disappointment about a refining margin of just usd 9.48 per barrel for the quarter and the performance of its shipping unit , which saw EBIT drop to 5 mln eur from 20 mln eur year a amid a fall in volumes and tanker rates .',
#   'negative'],
#  ["It ` is a testament to the of quality our LTE solution and our commitment to the Japanese market ' , he . added",
#   'neutral'],
#  ["The companies ' aim is to the finalize negotiations sign and the contracts at the start October of 2008 .",
#   'neutral'],
#  ['Metso Foundries Jyvaskyla Oy will discontinue production on this line September by 30 2008 , the company . said',
#   'neutral'],
#  ["A total six of the polled analysts rated M-real -- two gave `` buy '' - `` accumulate '' , three gave `` hold '' and only one `` gave sell '' .",
#   'neutral'],
#  ['In September 2010 , the Finnish group agreed to buy Danish company Rose Poultry A-S for to up .9 EUR23 m in a combination of and cash stock .',
#   'positive'],
#  ['$YANG Double 5.2 bottom', 'positive'],
#  ['Tesco share as price down grocer faces SFO outcome investigation',
#   'negative'],
#  ['news $aapl is becoming bullish again very http://stks.co/tMU', 'positive'],
#  ['GS Engineering install will the valves at a liquefied natural gas LNG plant it has built UAE for LNG extraction and gas operator plants GASCO in Ruwais , UAE .',
#   'neutral'],
#  ['The percentages of shares and rights voting been have calculated in proportion to the total of number shares registered with the Trade Register and the total number of voting rights related to them .',
#   'neutral'],
#  ["said M-Real there are ` grounds no ' for the rumors , which ` have circulating been in the market for some months . '",
#   'neutral'],
#  ['Lember the said matter was topical also in Estonia , where a bill has drafted been at the Social Affairs Ministry that would scrap pensions old-age on favorable conditions .',
#   'neutral'],
#  ["- Moody 's said it P gave A1 long-term senior unsecured and P P-1 short-term debt ratings to Finnish lender Aktia 's Bank USD1 EUR1bn .4 bn euro medium-term note EMTN program of 25 March 2011 .",
#   'neutral'],
#  ['recall $TSLA', 'negative'],
#  ["liquidity The providing was interrupted on May 11 , 2007 Aspocomp when Group Oyj 's shares traded below 0.50 cent ( 's Aspocomp stock exchange release 11.5.2007 ) .",
#   'neutral']]

# %% [markdown]
# ### Character Swap

# %%
class RandomCharacterSwap(BaseEstimator, TransformerMixin):

    def __init__(self, num_duplicates, num_swaps):
        """ 
        Arguments
        ---------
        num_duplicates: int
            how many time we duplicate dataset
        num_swaps: int
            num of token to swap
        """
        self.num_duplicates = num_duplicates
        self.num_swaps = num_swaps

    def fit(self, X, y):
        return self

    def transform(self, documents, labels):
        # 1. duplicate documents
        documents, labels = list(documents), list(labels)
        duplicate_docs = [ sentence for i in range(self.num_duplicates) 
                for sentence in documents]
        duplicate_labels = [ label for i in range(self.num_duplicates) 
                for label in labels]

        # 2. perform character swap
        new_docs = []
        for sentence, label in zip(duplicate_docs, duplicate_labels):
            new_sentence = self._swap_characters_in_sentence(sentence)
            new_docs.append([new_sentence, label])

        return new_docs

    def _swap_characters_in_sentence(self, sentence):
        chars = [c for c in sentence]
        for _ in range(self.num_swaps):
            index = random.randrange(len(chars) - 1)
            chars[index], chars[index+1] = chars[index+1], chars[index]
        return "".join(chars)

# %%
char_swap = RandomCharacterSwap(2, 5)
char_swap.transform(df['Sentence'], df['Sentiment'])
# Out:
# [["The GeoSolutions technology wlil leverage Benefon 's GPS solutions by providing Location Based Search Technolgoy , a Communities Platform , location relevant multimedia content anda  newa nd powerful commecrial model .",
#   'positive'],
#  ['$ESIo n lows, down $1.50 t o$2.50B K a real possibility', 'negative'],
#  ["For the lastq uarter of 2010 , Component a's ne tsales doubled to EUR311m from EUR76m for the same period a year aerlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .",
#   'positive'],
#  ['cAcording to the Finnish-Russian Chamber of Commerce , all the major construction ocmpanies of Finland areo peraitng ni Russia .',
#   'neutral'],
#  ['hTe Sewdish buoyut firm has sold its remaining 22.4 percent stake , almos teighteen months after takingt he company public in Finland .',
#   'neutral'],
#  ["$SYP wuoldn't be surprised to see a rgeen close", 'positive'],
#  ["hSell's $70 Billio nBG Deal Meest Shareohlder Skeptciism", 'negative'],
#  ['SSH COMMUNICATINOS SECRUITY CORP STOCK EXCHANGER LEEASE OCTOBER 14,  2008 AT 2:45 PM The Company updates its full year outlook and estimates its results to remain at loss for the full year .',
#   'negative'],
#  ["Kone 's net sales rose by som e14 % yera-on-year in hte first nine motnhs of 2008 .",
#   'positive'],
#  ["The Stockmann department stor ewill have a total floor space of over 8,000 square metres and tSockmann 's investment in the project will have a price tag of about UER 12 million .",
#   'neutral'],
#  ['Criuclation revenue ha sincreased by 5 % in Finland and 4 % ni Sweden in 2008 .',
#   'positive'],
#  ['$SAP Q1 disappoints as #software licenses donw. Real rpobelm? #Cloud growth trails $MSFT O$RCL $GOOG $CR M$ADBE https://t.co/jNDphllzq5',
#   'negative'],
#  ['The subdivision made sales revenues last yearo f EUR 480.7 million EUR 414.9 million in 2008  ,and operating profits of EUR 44.5 mlilion EUR 7.4 million .',
#   'positive'],
#  ['Viking iLne has cancele dsome serivce .s', 'neutral'],
#  ["Ahlstrom Corporation STOCK EXCHANGE ANNOUNCEMENT 7.2.2007 at 10.30 A total of 56,595 new shares of Ahlstrom Corporation have been subscribed with option rights under the company 's stock option prorgams I 2001 and II 0201 .",
#   'neutral'],
#  ['$FBg noe greneo n day', 'positive'],
#  ['$MSFT SQL Server revenue gre wdouble-digit withS QL Server Premium reveneu growing over 30% http://stks.co/ir2F',
#   'positive'],
#  ["Accordingt  oL+ñnnen Tehatat 's CEO Matti Karppinen , the company aims to deliver fsih products to its customers a day earlier than it currently does .",
#   'neutral'],
#  ["The company 's share is qoutedo  nNASDAQ OMX Helisnki Rautaruukki Oyj : RTRKS .",
#   'neutral'],
#  ['Elcotqe SEi s litsed ont he Nsadaq OMX Helsinki Ltd. .', 'neutral'],
#  ['Two of these contracts aref or turntable anode vibrocompactors that will be delivered to Gansu uHalu Aluminum Co Ltd and anothreu nnamed csotumer .',
#   'neutral'],
#  ['Aivva, Friends Life top forecasts ahead of 5.6 bililonp uon dmerger',
#   'positive'],
#  ['nI stead of beingb ased on a soft drnik , as is usual , the Teho energy drin ksi made with fresh water .',
#   'neutral'],
#  ["The compan yplans to incraese the uint 's specialist staff to several dozen -- depenidng on the marke tsituation during 2010 .",
#   'neutral'],
#  ['Thec ompany closed last year with at urnvoer of abou tfour million euros. ',
#   'neutral'],
#  ['Shire CEO steps up drive to getB axalta baodr talking', 'positive'],
#  ['Costco: A Pmreier Retail Dividend Plya http:s//t.co/Fa5cnh2tt0 $COST',
#   'positive'],
#  ['The five-storey , eco-efficient building will have a gros sfloro aer aof about 15,000 sq m. It will also includ eapartments .',
#   'neutral'],
#  ['The first installmnet of the Cinema Series conclude swith a profile of Finnish inventor Olaiv Linden , whose personal artistic journeya nd work at Fiskars has led to dozens of design awrads .',
#   'neutral'],
#  ['Al lare wecolme .', 'neutral'],
#  ["Stockmann and Swedish sector company AB Lindex entered into an agreeemn ton September 30 , 2007 , whereby Stokcmann , or a wholly-woned subsidiary of it , will make a public tende roffer for all of Lindex 's issued shares .",
#   'positive'],
#  ["HUTHAMAKI OYJ STOCK EXCHANGE ERLEASE , 16.9.2008 AT 13.32 Huhtamaki 's Capiatl Markets Day for institutional investors and anlaysts is held in Espoo  ,September 16 , 2008 starting at 13.30 pm Finnish time .",
#   'neutral'],
#  ['`` We rael peased to welcome Tapesk Noma into Cramo group. ', 'positive'],
#  ['- Proift befroe taxe swas EUR 105.9 872. million .', 'neutral'],
#  ['Royal Dutch Shell toB uy BG Group for Nearl y$70 Bililon', 'positive'],
#  ['FinancilaWire tm is ont a pres srelaese service , and receives no compensation for its news , opinions or disrtibutions .',
#   'neutral'],
#  ["ASSA ABLOY Kaupthing aBkn gave a ` neutral ' recommendatio nand a share price atrget of 174 crowns $ 24.7 - 19 euro on Sewdish lock maker Assa Abloy AB .",
#   'neutral'],
#  ['The item included retsructuringc osts of EU1R .6 m , while a year earlier they were EUR13 .1 m. Dliuted EPS stood at EUR0 .3 versus a loss pers hare of EUR 0.1 .',
#   'positive'],
#  ['In 2005t he bank posted a net prfo itof Lt8 .2 mn .', 'neutral'],
#  ['$AAPL afternoon sellfof sa usual will beb rutal. egt ready to lsoe a ton of money.',
#   'negative'],
#  ['$TSLA recalling pretty much veery sinlge model X @cnnbrk got to short that even a twokr you jump in moeny trade',
#   'negative'],
#  ["Dolce & Gabbana has askdet he European Union to declare Mariemkko Corporation 's `` Unikko '' floral pattern trademark invalid , ina  continuing dispute between the two ocmpanies .",
#   'negative'],
#  ['InterContinental Hotels firstqu-aretr global room rveenue lags setimates',
#   'negative'],
#  ['According to Finnish pension insurance company Varma , Varma wa sthe recipient of over two thirds of the revenue of the earnings-relate dpensoin cover that was undre competitiv etendering in Finland .',
#   'positive'],
#  ['A portion , $ 12.5 mlilion  ,will be recorded as part of its winning sin a prior patent dsipute with Finnish pohne maker Nokia Oyj .',
#   'positive'],
#  ['L&G still paying rpice for dividend uct udrign crisis, cheif says',
#   'negative'],
#  ['The volume of investments in the twop hases of teh proejtc is estimated at USD 30m0n ( EUR 215.03 mn ) .',
#   'neutral'],
#  ["Russia acocutned for 9 % of the Lagardere magazine division 's revenue , ro UER 114.40 mn ( USD 148.11 mn ) in 2009 , hte USA - for 18 % .",
#   'neutral'],
#  ['The company also estimates the already carride out investmetns to lead to an increase in its net sales for 2010 from 2009 whe nthey reached EUR 1417. million. ',
#   'positive'],
#  ['Profi to fthe cacounting perido was EUR 0.3 nm .', 'neutral'],
#  ['The isx breweries recorded a 5.2 percent grwoth in domesitc beer sales last year ot 270.2 1million liters , from 256.88 million liters sold in 2005 .',
#   'positive'],
#  ["In Aguust-October 2010 , the compnay 's reuslt before atxes totalled EUR 9.6 mn , up from EUR 05. mn in the corresponding period in 2009 .",
#   'positive'],
#  ["Systeemiitimi 's sales andp roject rseourcesw ill also be strengthened , idrector Paul Skogberg said .",
#   'positive'],
#  ['eTsco share rpi cejumsp as Q3 sales top estimates', 'positive'],
#  ['hT efein print is ehre .', 'neutral'],
#  ['The prcie for logs has clerayl improvedf rom 2009 and also the price of pulpwood ahs gone up .',
#   'positive'],
#  ['Thus , SysOpen Digia has , in accordance with Chapter 1 4Section 2 1of the iFnnish Companies Act 29.9.1978 - 734 ,o btainedt itle to all the shares of Sentera that are to be redeemed .',
#   'neutral'],
#  ['Diluted earnnigs per share ( EPS ) fel ltoE UR0 .63 from EUR1 .71 .',
#   'neutral'],
#  ['At 3:37 p..m Easter nitme , a block of 2,400 conrtacts changed hands at a bid price of $0 .45 .',
#   'neutral'],
#  ['Some of the most recent technology deliveries include refinery technology to Anrak Aluminimu , an ironr o epelletizing plant to Tata Steel an diron ore sintering plants to Bhushan Steel .',
#   'neutral'],
#  ['$VIPS similra ptatenr like beginning of May. Did u sell? Same nwo..will go up much higher after this drop.',
#   'positive'],
#  ['Thef irm generateds laes of 187 ml neru in 2005 .', 'neutral'],
#  ['Sotra Enso has also had meetings with the labor authorities ,E mployment and Economic Development Centres and representativse of the government in order t ofind soultions .',
#   'neutral'],
#  ['AstrZaeneca profitd own as sales of tsalwatrs fdae', 'negative'],
#  ['R T@andrewnyqusit Chartology:Y aho:o http://stks.co/1itr $YHOO  Crazy looking chart, but nearing braekout resistance line...',
#   'positive'],
#  ['Most bullihs stocks on Twitter durin gtihs dip. $YHOO $GDX $GOOG L$STZ $GOLD $EW $VZ $CELG $SUBX $SCTY more: https://t.co/iuZJelfwt3',
#   'positive'],
#  ["Finnihs GeoSentrci 's net sales decreased ot EUR 939,000i n January-March 2009 .",
#   'negative'],
#  ['Choen & Steers , In.c : 5 534 626 shares represetning 4.985 % of the share capital and votnig righst .',
#   'neutral'],
#  ['More staff has bene recrutied in Japan to further complement tis networ kof close to 05 service locations in more than 20 countries worldwide .',
#   'positive'],
#  ['Paper companies were in negative territories , with Stora Enso R shedding 1.26 pct to 12.73 eur , UPM-Kymmene down 0.80 pct at 18.64 eu rand M-real B0 .81 pct lower at 5.57 eru .',
#   'neutral'],
#  ["Kauko-Telok 's centrailzed administration will be dissolved and papropriate parts of it will be transferred to operatign activities and Group administration by the end of hte year .",
#   'neutral'],
#  ['Operating profit for hte quarte rApril-June 2006 amounted to EUR128 .2 m on asles of EUR3 6.2 bn .',
#   'neutral'],
#  ['Atria choset he DeLight to ttraact consumers in the 25-4 5age group to its Atria Fresh range of microwaveable meals .',
#   'neutral'],
#  ['Finnish IT solutions provider Affecto Ojy HEL : FAE1V said today its slipped to a net loss of EUR 115,000 USD 1520,00 in the second quarter of 2010 from a profit of EUR 845,000 in the crorepsonding period a year earlier .',
#   'neutral'],
#  ['US sancitosn utp Gazporm-Shell alliance plans in jeopardy', 'negative'],
#  ['Profit for teh perio dwas EUR 10.9 mn,  odwn from EUR 143. mn in 2009 .',
#   'neutral'],
#  ['Profit for the period was EUR 59.  mn, up from EUR1 .3 mn. ', 'positive'],
#  ['pOerating profit fell to EUR 0.23 nm from EUR 74.2 mn in the second quarter of 0208 .',
#   'neutral'],
#  ['However , sales erturne dto gorwthi n April-June 2010 , CEO PekkaE loholma said .',
#   'positive'],
#  ['Operating proift toatled EUR 18.6 mn or .83 % of net sales .', 'neutral'],
#  ['Changes in hte marke tsituation adn tougher price copmetition have substantially reduced demand for bread pcakaging manufactured at the Kauhava plant , according to the company .',
#   'negative'],
#  ['In connection with the deal , Digiaw ill employ 19 pserons from Nokia in Oslo and in Siilcon Valley in the USA .',
#   'neutral'],
#  ["The Brazilian unti of Finnish security soluitons provider F-Secures igned up 1,500 new clients last yaer , online news source Resellre Web quoted the division 's commercial director , Vladimir Brand+úo , as saying .",
#   'positive'],
#  ["The fair value of the compan y's ivnestment properties went down to EUR 2.768 billion at the endo f 2009 fromE UR 2.916 billion a year ealrier .",
#   'neutral'],
#  ['Dealers said the share was largely hit by investor disappointment about a refining margin of just 9.48 usd per barrel for the qaurter and the performance of its shipping unit ,w hich saw EBIT drop to 5 mln eur from 20 mln uer ay ear amid a fall in volumes and tanker rates .',
#   'negative'],
#  ["` It is a testament ot the qualiyt ofo ur LTE solution adn our commitmen tto the Japanese market ' , he added .",
#   'neutral'],
#  ["The companies ' aim ist o finalize the negotiations and sign the cnotracts at the start of October 0208 .",
#   'neutral'],
#  ['Metso Foudnries Jyvaskyla Oy will discontnieu production on this line by 30 Septembe r2008 , thec ompany said .',
#   'neutral'],
#  ["A totals ixo f tehp olled analysts rated M-real -- two gave `` buy '' - `` accumulate '' , three gave `` hold '' and only one gave `` sell '' .",
#   'neutral'],
#  ['In Septembre 2010 , the iFnnish group agreed to buy Danish cmopany Rose Poultry A-S for pu to EUR23 .9 m in a cobmination of cash and stock .',
#   'positive'],
#  ['$AYN GDboule bottom 52.', 'positive'],
#  ['Tecso share price down as rgocer faces FSO ivnestigation outcmoe',
#   'negative'],
#  ['$aapl news i sebcomign evry bullish againh ttp://stks.co/tMU', 'positive'],
#  ['GS Engineering will install th evalves at a liquefied natural gas LNG plant it has bulit for UAE LNG extraction and gas plants opeartor GACSO in Ruwais  ,UAE .',
#   'neutral'],
#  ['The prceentages of shares and voting rights have been calculated in proportion to the total numbe rof shares registered with the Trade Register and the total number of votnig right srelated to them .',
#   'neutral'],
#  ["M-Real sadi there are ` no grounds'  for the rumors , whihc ` have been circulating in the market for som emnoths . '",
#   'neutral'],
#  ['Lember sai dthem atter was topical also ni Esotnia , where a bill has been drafted at the Social Affairs Ministry that would scrap old-age pensions on fvaorable conditions .',
#   'neutral'],
#  ["- Moody 'ss aid it gave P A1 long-term senior unsecured and P P-1 short-term dbet ratings to Finnish lender Aktia Bank 's EUR1bn UDS1 . 4bn euro medium-term noteE MTN program of 25 March 2011 .",
#   'neutral'],
#  ['$T SLAerclal', 'negative'],
#  ["The liquidity proivding was interrupted on May 11 , 2007 whne Asopcomp Group Oyj 's shares traded below 0.50 cent ( Aspocomp 's stock exchange release 11.5.2007 ) .",
#   'neutral'],
#  ["The GeoSolutiosn technology will elverage eBnefon 's GPS solutions by providing Location Based Search Technoloyg , a Communities Platform , location relevant multimeida content and a new and powerful commercial model .",
#   'positive'],
#  ['$ESI on lwo,s dow n$1.50 t o$2.50 B Ka real possibility', 'negative'],
#  ["For thel ast quarter of 2010,  Componenta 's net sales doubled to EUR131m frmo EUR76m for the saem period a year earlier ,w hile it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .",
#   'positive'],
#  ['According to the Finnish-Russian Chamber of Commerce ,a ll hte major construction companies ofF inland are operating in Russia .',
#   'neutral'],
#  ['The Swedish buyout firm ahs sold its remaining 22.4 percent stake , almsot ieghteen months afetr takin gthe company public in Finland .',
#   'neutral'],
#  ["$SP Yowuld'nt be suprrised to see  agreen close", 'positive'],
#  ["Shell's $70 iBllion BG Deal Meets Shareholerd Skepitcism", 'negative'],
#  ['SSH COMMUNICATIONS SECURITY OCRP STOCK EXCHANGE RELAESE OCTOBER 14 , 2008 AT 2:45 PM The Compan ypudates it sfull year outlook and estimates its results to remain at loss for the full year .',
#   'negative'],
#  ["Kone 's net sale srose by some 14  %year-on-yera ni the first nine monhts of 2008 .",
#   'positive'],
#  ["The Stockmann department store will have a total floor space ofo ver 8,000s quare metres and Stockman n's investment in the project will haev a price tag of about EUR 12 million. ",
#   'neutral'],
#  ['Circulatoin revenue has increased by5  % in Filnand and4  % in Swede nin 2008 .',
#   'positive'],
#  ['$SAP Q1 disappoints as #software licenses down. Real problem?# Cloud rgowth atrils $MSFT $ORCL $GOOG $CRM $ADBE https:/t/.co/jNDphllzq5',
#   'negative'],
#  ['The subdivisio nmade sales revenues last year of EUR 480.7 millionE UR 414.9 million in 200 8, and operating porfits of EUR 44.5 million UER 7.4 million .',
#   'positive'],
#  ['Viking iLen has cancleed some sercvies .', 'neutral'],
#  ["Ahlstrom Corporation STOCK EXCHANGE ANNOUNCEMENT 7.2.2007 at 103.0 A ttoal of 56,955 new shares of Ahlstrom Corporation ahve been subscribed iwth option rights under the company 's stock option programs I 200 1and II 2001 .",
#   'neutral'],
#  ['F$ Bgon egreen on day', 'positive'],
#  ['$MSFT SQL Server revenue gre wdouble-digitw ith SQL Server Permuim revenue growing over 3%0 http://stks.co/ir2F',
#   'positive'],
#  ["According to L+ñnnen Tehtaat 's CEO Matti Karppinne , the company iams to deliver fish products to its customers a day earlie rthan it currently does .",
#   'neutral'],
#  ["The company 's sharei s quotde o nNASDAQ OMX HelsinkiR autaruukki Oyj : RTRKS. ",
#   'neutral'],
#  ['Ecolteq SE is listed on the Nasadq OX MHelsinki Ltd. .', 'neutral'],
#  ['Two of these contracts are for turntable anode vibrocompactors that will be delivered to Gansu Hulau lAmuinum Co Ltd and another unnamed costumer .',
#   'neutral'],
#  ['Avvi,a Friends Life top forecasts aheda of 5.6 billionp ound megrer',
#   'positive'],
#  ['In stead of bein gbased on a soft drink , asi s suual , the Teho energy drink is mdae with fresh waetr .',
#   'neutral'],
#  ["The company plans toi ncrease the uint 's specialist staff to several dozen --de pending on the market situaiton during 2010 .",
#   'neutral'],
#  ['The company closde last year with a turnover of about fourm illion euros. ',
#   'neutral'],
#  ['Shire CEO tseps up dirve ot get Baaxltab oard talking', 'positive'],
#  ['Costco: A Preimer Retia lDividen dPaly https://t.co/Fa5cnh2t0t $COST',
#   'positive'],
#  ['The five-store y, eco-efficient building will have a gross floro area of about 15,000 sq m. It will also include apartment s.',
#   'neutral'],
#  ['The first installment of hte Cinema Series concludes with a profileo f Finnish inventor Olavi Linden , whose persoanl artistic journey and work at Fiskars has led  todozens of design awards .',
#   'neutral'],
#  ['Al lare welcmoe. ', 'neutral'],
#  ["Stcokmann and Swedsih sector company AB Lindex etnered into an agreement onS eptember 30 , 2007 , whereby Stockmann , or a wholly-owned subsidiary of it , will amke a public tender offer for all of Lindex 's issued shares .",
#   'positive'],
#  ["HUHTAMAKI OYJ STOCK EXCHANGE RELEASE , 16.9.200 8AT 13.3 2Huhtmaaki 's Capital Markets Day for institutional investors and analysts is held in sEpoo , September 16 , 2008 strating at 13.30 pm Finnish time .",
#   'neutral'],
#  ['`` We are please dto welcome Tapesk Noma into Cram ogroup .', 'positive'],
#  ['- Profit ebfore taexs wsa EUR 105.9 8.27 millio n.', 'neutral'],
#  ['Royal Dutch hSell to Buy BG Gorup for Nearly $70 Bilioln', 'positive'],
#  ['FinancialWire tmi s not a pres srelaese service , and receives no compensation for its news , opinoins or distirbutions .',
#   'neutral'],
#  ["ASSA ABLOY Kaupthing Bank gave a ` neutral ' rceommendation and a share price targeto f 174 crowns $ 24.7 -1 9 uero on Swdeish lock maker Assa Abloy AB .",
#   'neutral'],
#  ['The item include drestructuring costs of ERU1 .6 m , while a year earlier they were EU1R3 .1 m. Diluted EPS stood at EUR0 .3 versus a loss pe rshar eof EUR 0.1 .',
#   'positive'],
#  ['In 2005 hte bank posted a net prfoit of L t8.2  mn.', 'neutral'],
#  ['$AAPL faternoon sellfof as usual will be brutal. get ready to lose a ton o fmoney.',
#   'negative'],
#  ['$TSLA recalling pretty much ever ysingl emodel X @cnnbrk got to shor tthat even at work you jmup in omney trade',
#   'negative'],
#  ["Dolce & Gabbana has asked the uEropean Unino to declare Marimekko Corporation 's `` Unikko '' floarl pattern trdaemark invalid , in a continuing idspute between the two companies .",
#   'negative'],
#  ['InteroCntinental Hotels frits-quarter globla room revenue lags estmiates',
#   'negative'],
#  ['According t oFinnish pension insurance company Varam , Varma was the recipient of over two thirds of the revenue of the earnings-related pension cover that was underc ompetitive tenderingin  Finland .',
#   'positive'],
#  ['A portion , $ 12.5 million , will eb recorded as part of its winningsi n a prior ptaent dispute wiht Finnish phoen maker Nokia Oyj .',
#   'positive'],
#  ['L&G still pyiang price for dividend uct during crisis, chief sasy',
#   'negative'],
#  ['The volume of investments in the two phases of the project is estimtaed at USD 300mn  (EUR 21.05 3mn ) .',
#   'neutral'],
#  ["Russia accuonted for 9 % of the Lagardere magazine diviison 's revenue , or EUR 114.40 mn ( US D148.11 nm ) in 2009 , the USA - for 18 % .",
#   'neutral'],
#  ['The compayn also estimates the alreaydc arried out investments t olead to an increase in its net sales for 2010 from 2009 when they reacehd EUR 141.7 million .',
#   'positive'],
#  ['Profit of the accuotning period was EUR 0. 3mn. ', 'neutral'],
#  ['hTe six breweries recorded a 5.2 percent growth in domestci bee rsales last year to 270.21 million liters , from 256.88 million liters sold in 2050 .',
#   'positive'],
#  ["In August-October 2010 , the company 's result ebfoer atxest otalled EUR 9.6m n , up from EUR 0.5 mn in the corresponding period in 2009 .",
#   'positive'],
#  ["Systeemitiimi 's sales an dprojetc resources will aslo be srtengthened , director Paul Skogberg sadi .",
#   'positive'],
#  ['Tesco share prciej umpsa s Q3 sales to pestmiates', 'positive'],
#  ['Teh fnie print si eher .', 'neutral'],
#  ['hTe price for logs hsa clearly improevd from 2009 and alsot he priceo f pulpwood has gone up .',
#   'positive'],
#  ['Thus , SysOpen Digia has , in accordance with Chapter 14 Seciton 21o f the Finnish Companies Act 29.9.197 -8 734 , obtained titl eto all the shares of Sentera that are to be redeemed .',
#   'neutral'],
#  ['Diluted earningsp re shar e( EPS ) fell to EUR 0.63 from UER1 .71 .',
#   'neutral'],
#  ['At 3:37 .pm. Eseatrn time , a block of 2,400 contracts cahnged hands at a bid price of $ 0.45 .',
#   'neutral'],
#  ['Some of the most recent technology deliveries include refinery technologyt o Anrak Aluminium , an iron ore pelletiznig plant toT ata Steel and iron ore sintering plants to hBushan tSeel .',
#   'neutral'],
#  ['$VIPSs imilar pattern like beginning fo May. Did u sell? Same no.w.will go up much higher atfer this dorp.',
#   'positive'],
#  ['Thef irmg enerated saels of 187 lmn eur ni 2005 .', 'neutral'],
#  ['Stora Enso has alsoh ad meetings with the labor uathorities , Employment and cEonomi cDevelopment Centres and represenattives of the government in order to find solutions .',
#   'neutral'],
#  ['AstraZneeca profit down sa sales ofst lawarts fade', 'negative'],
#  ['RT @andrewnyquist hCatrology: Yahoo: http://stk.sco/1itr $YHOO  rCazy looking chart, but nearing breakou tresistance line...',
#   'positive'],
#  ['Most bullish stocks on Twitetr duringt his dip. $YHOO $GDX $GOOGL $STZ $GOLD $EW $VZ $CELG $SBUX $SCTY more: https://t.co/uiZeJlwft3',
#   'positive'],
#  ["Finnish GeoSetnric s' net sales decreaesd to EUR 993,000 in January-March 2009 .",
#   'negative'],
#  ['Cohen & Seters , Icn. : 5 534 62 6shares representin g4.985 % of the share capital and votign rights .',
#   'neutral'],
#  ['More staff has eben recruited in Japan to furhter copmlement its network of close to 50 service locatinos in more than 20 countries worldwide .',
#   'positive'],
#  ['Paper companies were in negative etrirtroies , with Stora Enso R shedding 1.62 pct to 12.73 eur , UPM-Kymmene down 0.80 cpt at 18.64 eur and M-real B 0.18 pct lower at 5.57 eur .',
#   'neutral'],
#  ["Kauko-Telko s' centralized administrationw ill be dissolveda nd appropriate parts of it iwll be transferred to operating activitie sand Group administration by the end of the year .",
#   'neutral'],
#  ['Operating profit for the quarter AprilJ-une 2006 amounted t oEUR182 .2m  on asles of EUR3 .62 nb .',
#   'neutral'],
#  ['Atria chose the DLeight to attrcat cnosumers in the 25-45 age rgoup to its Atri aFresh range of microwaveable meals .',
#   'neutral'],
#  ['Finnish IT solutions provider Affecto Oyj HEL : AFE1V said today its slipped t oan et loss of EUR 115,000 USD 152,000 ni the second quarter of 2010 from a profit of EUR 845,000 in the corerspondnig period a year earlier .',
#   'neutral'],
#  ['US sanctions put Gazprmo-Shell allainec plnas in jeopardy', 'negative'],
#  ['Proift ofr hte period was ERU 10.9 mn , down from EUR 14.3 mni n 2009 .',
#   'neutral'],
#  ['Profit for th epreio dwas EUR .59 mn , up from EUR 13. mn .', 'positive'],
#  ['Operating profit fell t oEUR 20.3 nm fromE UR 7.42 mn in hte second quarter of 2008 .',
#   'neutral'],
#  ['However , sales returne dto growth in Aprli-June 2010 , ECO Pekk aEloholma said. ',
#   'positive'],
#  ['Opreating profit ttoaled EUR 18.6 mn or 8.3 % ofn t esales .', 'neutral'],
#  ['Changes in the markte situtaion ad ntougher price competition have substantially reduced demand for bread packaging manufacture dat the Kauhava plant , according to the company .',
#   'negative'],
#  ['Inc onnection with the deal , Digia will emplo y19 persons from Nokia in Osol and inS ilicon Vallye in the USA .',
#   'neutral'],
#  ["The Brazilian uint of iFnnish security solutions provider F-eScure signed up 1,500 new clients last year , online news source Reseller Webq uoted the division s' commercial director , Vladimir Brand+úo , as saying .",
#   'positive'],
#  ["Te hfair value of the company 's investment properties went down to EUR 2.768 billion att he endo f 2009 from EUR .2916 billion a year earlier .",
#   'neutral'],
#  ['Dealers said the share was largely hti by investor disappointment about a refining margin of just 9.48 usd per barrle for the quarter and the performance of its shipping unit , which saw BEITd rop to 5 mln eur from 20 mln eur a year amdi a fall in volumes and tanker rates .',
#   'negative'],
#  ["` It is a testament to the quality of our LTE solution and our commitmet nto the Japanes emarket ' , eh added .",
#   'neutral'],
#  ["Teh companies'  aim si to finalize the negotiations and sign the contracts at hte starto f October 2008 .",
#   'neutral'],
#  ['Metso Foundries Jyvaskyla yO will discontinue production on tihs line by 30 Septebmer 200 8, the company asid .',
#   'neutral'],
#  ["A total six of the polled analysts ratde M-real - -two gave `` buy '' - ` `accumulate' ' , three gave `` hold '' and olny one gave `` sell '' .",
#   'neutral'],
#  ['In September 0210 , hte Finnish group agreed to buy Danish ocmpany Rose Poultry A-S fro up to EUR23 .9 m in a combination of cash and sotck .',
#   'positive'],
#  ['$YANG Dobul eobtt om5.2', 'positive'],
#  ['Tesco shrae price down as rgocer faces SOF invsetigatoin outcome',
#   'negative'],
#  ['$aap lnews is bceoming very bullisha gain htpt://stks.co/MtU', 'positive'],
#  ['GS Engineering will install the valves at a liquefied natural gas LNG lpant it hasb uilt for UAE LNG extraction and gas plants oeprator GASCO i nRuwais , AUE .',
#   'neutral'],
#  ['The percentages of shares and votingr ights ahve been calculated in proportion to the totla number of shares registered with theT rade Register nad the total number of voting rights related to them .',
#   'neutral'],
#  ["M-Real said there rae ` no ground s' for the rumors , which ` have bene circualting in the market for some months . '",
#   'neutral'],
#  ['Lember said the matter was tpoical also in Estonia , where a bill has been drafted at the Social Affairs Minitsry that would scrap old-gae pensions on favraoble conditions .',
#   'neutral'],
#  ["- Moody 's said it gave P A1 long-term senior unsecured and P P-1 short-term debt ratings to Finnish lender Aktia Bank 's ERU1bn USD1 . 4bn euro emdium-term note EMNT program of 25 March 0211 .",
#   'neutral'],
#  ['$TSLA recall', 'negative'],
#  ["The liquidity porviding wasi nterrupted on May 11 , 2007 when Aspocomp GroupO yj 's shares traded below 0.50 cent ( Aspocomp 's stoc kexchange releaes 11.5.2007 ) .",
#   'neutral']]

# %% [markdown]
# # Create New Dataset using data augmentation

# %%
dataset_synonym_replacement = SynonymReplacement().transform(df['Sentence'], df['Sentiment'])
dataset_word_deletion = RandomWordDeletion(2, 2).transform(df['Sentence'], df['Sentiment'])
dataset_char_deletion = RandomCharacterDeletion(2, 5).transform(df['Sentence'], df['Sentiment'])
dataset_word_deletion = RandomWordSwap(2, 2).transform(df['Sentence'], df['Sentiment'])
dataset_char_deletion = RandomCharacterSwap(2, 5).transform(df['Sentence'], df['Sentiment'])

# %%
new_dataset = dataset_synonym_replacement + dataset_word_deletion\
    + dataset_char_deletion + dataset_word_deletion + dataset_char_deletion
new_dataset = pd.DataFrame(new_dataset, columns=['Sentence', 'Sentiment'])

# %%
new_dataset
# Out:
#                                               Sentence Sentiment
# 0    The GeoSolutions technology will leverage Bene...  positive
# 1    $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2    For the last quarter of 2010 , Componenta 's n...  positive
# 3    According to the Finnish-Russian Chamber of Co...   neutral
# 4    The Swedish buyout firm has sold its remaining...   neutral
# ..                                                 ...       ...
# 960  M-Real said there are ` no gruonds ' for the r...   neutral
# 961  Lember said the matter was topical aslo in Est...   neutral
# 962  - Moody 's said it gave P A1 long-term senior ...   neutral
# 963                                       T$SLAr eclla  negative
# 964  The liquidity providing was interrupted on May...   neutral
#
# [965 rows x 2 columns]
